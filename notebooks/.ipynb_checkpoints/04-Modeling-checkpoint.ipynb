# %% [markdown]
# # Modeling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pickle
import csv

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.linear_model import Lasso, LinearRegression, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_squared_error 
from sklearn.svm import SVR
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsRegressor
from sklearn import preprocessing

import time

np.random.seed(42)
# Out:
# /Users/nelson/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# ### Load the Data

# %%
X_train_sc = pd.read_csv('../data/X_train_sc.csv', header=None)
X_test_sc = pd.read_csv('../data/X_test_sc.csv', header=None)

# %%
X_train = pd.read_csv('../data/X_train.csv')
X_test = pd.read_csv('../data/X_test.csv')

# %%
y_train = pd.read_pickle('../pickles/y_train.pkl')
y_test = pd.read_pickle('../pickles/y_test.pkl')

# %%
ss = pd.read_pickle('../pickles/standard_scaler.pkl')

# %%
y_train.mean()
# Out:
# 103.21479039479041

# %%
y_test.mean()
# Out:
# 103.2904052734375

# %%
r2_score(y_test, [y_test.mean()] * len(y_test))
# Out:
# 0.0

# %%
np.sqrt(mean_squared_error(y_test, [y_test.mean()] * len(y_test)))
# Out:
# 4.365981019821426

# %%
X_train_sc.shape, X_test_sc.shape
# Out:
# ((12285, 80), (4096, 80))

# %%
y_train.shape, y_test.shape
# Out:
# ((12285,), (4096,))

# %% [markdown]
# ### Modeling Functions

# %%
def modeling_func(pipe, params, X_train, X_test, y_train, y_test, cv=3):
    gs = GridSearchCV(pipe, param_grid=params, cv=cv)
    gs.fit(X_train, y_train)
    with open(f'../pickles/{"_".join(pipe.named_steps.keys())}{int(time.time())}.pkl', 'wb+') as f:
        pickle.dump(gs, f)
    return gs

# %%
def model_feature_plotting_func(x, y, pipe):
    plt.figure(figsize=(25,12))

    sns.set(style="white")
    sns.set_context("poster")

    plt.title(f'{"_".join(pipe.named_steps.keys()).upper()} Feature Importances (Top 20)', fontsize=35, pad=40)

    a = sns.barplot(x.head(20).values,
                    y.index[0:20].values, 
                    palette='pastel', saturation=.5, edgecolor='k')

    plt.xlabel('Weights', fontsize=25, labelpad=20)

    a.tick_params(labelsize=22,labelcolor="k")
    sns.despine()

    plt.tight_layout();
    plt.savefig(f'../plots/{"_".join(pipe.named_steps.keys())}_feature_importance.png')

# %%
def predictions_plotting_func(pipe, predictions, y_test):
    plt.figure(figsize=(25,12))
    plt.title(f'{"_".join(pipe.named_steps.keys()).upper()} Predictions vs Actuals', fontsize=30, pad=40)

    plt.scatter(predictions, y_test, color='#069af3', s=200, edgecolors='k', alpha=.4, lw=2)
    plt.plot([0, 122], [0, 122], color='#fd3c06', lw=7, alpha=.8)

    plt.xlim([70, 120])
    plt.ylim([70, 120])

    plt.xlabel('Predictions', fontsize=30, labelpad=20)
    plt.ylabel('Actuals', fontsize=30, labelpad=20)

    plt.tick_params(labelsize=25,labelcolor="k")

    sns.despine()

    plt.legend(['Line of Best Fit'], fontsize=30)
    plt.tight_layout()
    
    plt.savefig(f'../plots/{"_".join(pipe.named_steps.keys())}_model_predictions.png')

# %% [markdown]
# ## Linear Models

# %% [markdown]
# ### GridSearch with Ridge (L2)

# %%
gs_rd = pd.read_pickle('../pickles/rid1539795639.pkl')

# %% [markdown]
# #### Pipeline and Parameter

# %%
pipe_rd = Pipeline([
    ('rid', Ridge())
])

# %%
np.logspace(-1,3,9)
# Out:
# array([1.00000000e-01, 3.16227766e-01, 1.00000000e+00, 3.16227766e+00,
#        1.00000000e+01, 3.16227766e+01, 1.00000000e+02, 3.16227766e+02,
#        1.00000000e+03])

# %%
params_rd = {
    'rid__alpha':np.logspace(-1, 3, 9)
}

# %% [markdown]
# #### Ridge Model

# %%
# gs_rd = modeling_func(pipe_rd, params_rd, X_train_sc, X_test_sc, y_train, y_test)

# %%
gs_rd.best_params_
# Out:
# {'rid__alpha': 31.622776601683793}

# %%
gs_rd.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('rid', Ridge(alpha=31.622776601683793, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001))])

# %%
gs_rd.score(X_train_sc, y_train)
# Out:
# 0.5158479079381048

# %%
gs_rd.score(X_test_sc, y_test)
# Out:
# 0.5041979420168723

# %% [markdown]
# ### GridSearch with Lasso (L1)

# %%
gs_la = pd.read_pickle('../pickles/la1539796474.pkl')

# %% [markdown]
# #### Pipeline and Parameter

# %%
pipe_la = Pipeline([
    ('la', Lasso())
])

# %%
params_la = {
    'la__alpha':np.logspace(-3, 3, 7)
}

# %% [markdown]
# #### Lasso Model

# %%
# gs_la = modeling_func(pipe_la, params_la, X_train_sc, X_test_sc, y_train, y_test)

# %%
gs_la.best_params_
# Out:
# {'la__alpha': 0.01}

# %%
gs_la.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('la', Lasso(alpha=0.01, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False))])

# %%
gs_la.score(X_train_sc, y_train)
# Out:
# 0.5141935832528688

# %%
gs_la.score(X_test_sc, y_test)
# Out:
# 0.5040682614801717

# %% [markdown]
# ### GridSearch with ElasticNet

# %%
gs_enet = pd.read_pickle('../pickles/enet1539795204.pkl')

# %% [markdown]
# #### Pipeline and Parameters

# %%
pipe_enet = Pipeline([
    ('enet', ElasticNet())
])

# %%
params_enet = {
    'enet__alpha': np.logspace(-3, 3, 7),
    'enet__l1_ratio': [.0001, .3, .5, .7, .9, 1]
}

# %% [markdown]
# #### ElasticNet Model

# %%
# gs_enet = modeling_func(pipe_enet, params_enet, X_train_sc, X_test_sc, y_train, y_test)

# %%
gs_enet.best_params_
# Out:
# {'enet__alpha': 0.01, 'enet__l1_ratio': 1}

# %%
gs_enet.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('enet', ElasticNet(alpha=0.01, copy_X=True, fit_intercept=True, l1_ratio=1,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False))])

# %%
gs_enet.score(X_train_sc, y_train)
# Out:
# 0.5141935832528688

# %%
gs_enet.score(X_test_sc, y_test)
# Out:
# 0.5040682614801717

# %% [markdown]
# ## Ensemble Models

# %% [markdown]
# ### GridSearch with RandomForestRegressor
#
# This will convert epoch back to datetime:
# - time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())

# %%
gs_rf = pd.read_pickle('../pickles/rf1539714652.pkl')

# %% [markdown]
# #### Pipeline and Parameters

# %%
pipe_rf = Pipeline([
    ('rf', RandomForestRegressor())
])

# %%
params_rf = {
    'rf__n_estimators':[130, 140, 150],
    'rf__max_depth':[20, 25, 30]
}

# %% [markdown]
# #### Random Forest Model

# %%
# gs_rf = modeling_func(pipe_rf, params_rf, X_train, X_test, y_train, y_test)

# %%
gs_rf.best_params_
# Out:
# {'rf__max_depth': 25, 'rf__n_estimators': 140}

# %%
gs_rf.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('rf', RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=25,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=140, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False))])

# %%
train = gs_rf.score(X_train, y_train)
test = gs_rf.score(X_test, y_test)

# %%
print(f'Model Train Score {train}')
print(f'Model Test Score {test}')
# Out:
# Model Train Score 0.941821592737002
# Model Test Score 0.603107782648939

# %% [markdown]
# #### Random Forest Feature Importances

# %%
rf_features = pd.DataFrame(gs_rf.best_estimator_.named_steps['rf'].feature_importances_.ravel(), 
                           index=X_train.columns, columns=['feature_importance'])
rf_features.sort_values('feature_importance', ascending=False, inplace=True)
rf_features.head()
# Out:
#                  feature_importance
# hit_distance_sc            0.423799
# launch_angle               0.197959
# weight                     0.030105
# ay                         0.028171
# plate_x                    0.022393

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(y_train[(X_train.game_year_2016 != 1) & (X_train.game_year_2017 != 1)], y_train[X_train.game_year_2016== 1])
# Out:
# Ttest_indResult(statistic=-1.6222343924722162, pvalue=0.10479383545547594)

# %%
ttest_ind(y_train[(X_train.game_year_2016 != 1) & (X_train.game_year_2017 != 1)], y_train[X_train.game_year_2017== 1])
# Out:
# Ttest_indResult(statistic=0.7662411222397761, pvalue=0.4435549304587384)

# %%
ttest_ind(y_train[X_train.game_year_2016 == 1], y_train[X_train.game_year_2017== 1])
# Out:
# Ttest_indResult(statistic=2.538878449184705, pvalue=0.011138247369622534)

# %%
y_train[X_train.game_year_2016 == 1]
# Out:
# array([101. , 106.2,  99.5, ..., 111.4, 104.6, 110.1])

# %%
y_train[X_train.game_year_2017== 1]
# Out:
# array([102.4, 105.9,  94.3, ..., 101.3, 100.7, 105.2])

# %%
model_feature_plotting_func(rf_features['feature_importance'], rf_features, pipe_rf)

# %% [markdown]
# #### Random Forest Predictions

# %%
predictions_rf = gs_rf.predict(X_test)
predictions_rf
# Out:
# array([105.19517324, 101.2758327 , 107.41785714, ..., 104.4847619 ,
#        106.80213861, 103.92607277])

# %%
predictions_rf.max(), y_test.max()
# Out:
# (115.20000000000002, 121.1)

# %%
predictions_rf.min(), y_test.min()
# Out:
# (91.09571428571428, 76.6)

# %%
predictions_plotting_func(pipe_rf, predictions_rf, y_test)

# %% [markdown]
# #### Random Forest Model Interpretations
#
# INPUT INTERPRETATION HERE

# %% [markdown]
# ### GridSeach with GradientBoostRegressor

# %%
gs_gb = pd.read_pickle('../pickles/gbr1539715514.pkl')

# %% [markdown]
# #### Pipeline and Parameters

# %%
pipe_gb = Pipeline([
    ('gbr', GradientBoostingRegressor())
])

# %%
params_gb = {
    'gbr__n_estimators':[200, 210, 220],
    'gbr__max_depth':[3, 5, 7]
}

# %% [markdown]
# #### Gradient Boost Model

# %%
gs_gb = modeling_func(pipe_gb, params_gb, X_train_sc, X_test_sc, y_train, y_test)

# %%
gs_gb.best_params_
# Out:
# {'gbr__max_depth': 3, 'gbr__n_estimators': 210}

# %%
gs_gb.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('gbr', GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=210, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False))])

# %%
test = gs_gb.score(X_test_sc, y_test)
train = gs_gb.score(X_train_sc, y_train)

# %%
print(f'Model Train {train}')
print(f'Model Test {test}')
# Out:
# Model Train 0.680384206966165
# Model Test 0.6165711841636452

# %% [markdown]
# #### Gradient Boost Feature Importance

# %%
columns = X_train.columns
coef_weights = pd.DataFrame(gs_gb.best_estimator_.named_steps['gbr'].feature_importances_.ravel(),
                            index=X_train.columns, columns=['coef_weights'])
coef_weights.sort_values('coef_weights', ascending=False, inplace=True)
coef_weights.head()
# Out:
#                  coef_weights
# launch_angle         0.165535
# hit_distance_sc      0.164041
# ay                   0.067055
# plate_x              0.062734
# weight               0.057066

# %%
model_feature_plotting_func(coef_weights['coef_weights'], coef_weights, pipe_gb)

# %% [markdown]
# #### Gradient Boost Predictions

# %%
predictions_gb = gs_gb.predict(X_test_sc)

# %%
predictions_gb
# Out:
# array([105.41697644, 100.43190058, 107.48483652, ..., 102.99259682,
#        106.73297381, 103.72525058])

# %%
predictions_gb.max(), y_test.max()
# Out:
# (115.82707069878175, 121.1)

# %%
predictions_gb.min(), y_test.min()
# Out:
# (90.54621308019175, 76.6)

# %%
r2_score(y_test, predictions_gb)
# Out:
# 0.6165711841636452

# %%
np.sqrt(mean_squared_error(y_test, predictions_gb))
# Out:
# 2.7034865764784137

# %%
predictions_plotting_func(pipe_gb, predictions_gb, y_test)

# %% [markdown]
# #### Gradient Boost Model Interpretation
#
# INPUT INTERPRETATION HERE

# %% [markdown]
# ### GridSearch with AdaBoostRegressor

# %%
gs_ada = pd.read_pickle('../pickles/ada1539716634.pkl')

# %% [markdown]
# #### Pipeline and Parameters

# %%
pipe_ada = Pipeline([
    ('ada', AdaBoostRegressor())
])

# %%
params_ada = {
    'ada__n_estimators':[40, 50, 60]
}

# %% [markdown]
# #### AdaBoost Model

# %%
gs_ada = modeling_func(pipe_ada, params_ada, X_train_sc, X_test_sc, y_train, y_test)

# %%
gs_ada.best_params_
# Out:
# {'ada__n_estimators': 50}

# %%
gs_ada.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('ada', AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#          n_estimators=50, random_state=None))])

# %%
train = gs_ada.score(X_train_sc, y_train)
test = gs_ada.score(X_test_sc, y_test)

# %%
print(f'Model Train Score: {train}')
print(f'Model Test Score: {test}')
# Out:
# Model Train Score: 0.4836915544103218
# Model Test Score: 0.452611043715773

# %% [markdown]
# #### AdaBoost Feature Importances

# %%
columns = X_train.columns
coef_weights = pd.DataFrame(gs_ada.best_estimator_.named_steps['ada'].feature_importances_.ravel(),
                            index=X_train.columns, columns=['coef_weights'])
coef_weights.sort_values('coef_weights', ascending=False, inplace=True)
coef_weights.head()
# Out:
#                  coef_weights
# launch_angle         0.365462
# hit_distance_sc      0.319418
# weight               0.069602
# avg_ds               0.037025
# plate_x              0.029172

# %%
model_feature_plotting_func(coef_weights['coef_weights'], coef_weights, pipe_ada)

# %% [markdown]
# #### AdaBoost Predictions

# %%
predictions_ada = gs_ada.predict(X_test_sc)

# %%
predictions_ada
# Out:
# array([105.4174444 , 100.95279202, 105.21105232, ..., 101.94606332,
#        105.09064786, 103.18010282])

# %%
predictions_ada.max(), y_test.max()
# Out:
# (109.26810506566598, 121.1)

# %%
predictions_ada.min(), y_test.min()
# Out:
# (91.97112165178304, 76.6)

# %%
predictions_plotting_func(pipe_ada, predictions_ada, y_test)

# %% [markdown]
# #### AdaBoost Model Interpretation
#
# INPUT INTERPRETATION HERE
