# %% [markdown]
# # Major League Baseball Home Run Exit Velocities

# %%
import pandas as pd
import numpy as np
from scipy import stats 

# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

from bs4 import BeautifulSoup
import requests
import json

# %% [markdown]
# ### Import the Data
#
# Importing each home run hit from the following seasons: (16626 records)
# - 2015
# - 2016
# - 2017

# %%
hr_df = pd.read_csv('../data/home_runs_15_16_17.csv')
baseballs_df = pd.read_excel('../data/baseballs.xlsx')

# %%
hr_df.head()
# Out:
#   pitch_type game_date  release_speed  release_pos_x  release_pos_z  \
# 0         CH   6/10/17           84.5        -3.4020         6.4696
# 1         FF   4/28/17           97.1        -2.8091         5.9279
# 2         CU   6/23/15           86.7        -1.5647         5.3406
# 3         SL   9/28/17           89.5         2.0682         6.1177
# 4         SL   6/11/17           84.7        -1.9795         5.6860
#
#          player_name  batter  pitcher    events          description  \
# 0        Aaron Judge  592450   501957  home_run  hit_into_play_score
# 1        Aaron Judge  592450   592332  home_run  hit_into_play_score
# 2  Giancarlo Stanton  519317   593372  home_run  hit_into_play_score
# 3  Giancarlo Stanton  519317   571521  home_run  hit_into_play_score
# 4        Aaron Judge  592450   548337  home_run  hit_into_play_score
#
#            ...           home_score  away_score  bat_score  fld_score  \
# 0          ...                    0           0          0          0
# 1          ...                    2           9          2          9
# 2          ...                    0           0          0          0
# 3          ...                    5           1          5          1
# 4          ...                    7           3          7          3
#
#    post_away_score post_home_score post_bat_score post_fld_score  \
# 0                0               0              0              0
# 1                9               2              2              9
# 2                0               0              0              0
# 3                1               5              5              1
# 4                3               7              7              3
#
#   if_fielding_alignment of_fielding_alignment
# 0         Infield shift              Standard
# 1              Standard              Standard
# 2              Standard              Standard
# 3         Infield shift              Standard
# 4         Infield shift              Standard
#
# [5 rows x 89 columns]

# %%
col = [ 
    'umpire',
    'spin_dir',
    'spin_rate_deprecated',
    'break_angle_deprecated',
    'break_length_deprecated',
    'events',
    'description', 
    'des',
    'game_type', 
    'stand',
    'type', 
    'hit_location', 
    'balls', 
    'strikes', 
    'plate_z', 
    'on_3b', 
    'on_2b', 
    'on_1b', 
    'outs_when_up',
    'inning',
    'inning_topbot', 
    'hc_x', 
    'hc_y',
    'tfs_deprecated', 
    'tfs_zulu_deprecated', 
    'fielder_2', 
    'sv_id', 
    'pitcher.1', 
    'fielder_2.1', 
    'fielder_3', 
    'fielder_4', 
    'fielder_5', 
    'fielder_6', 
    'fielder_7', 
    'fielder_8', 
    'fielder_9', 
    'estimated_ba_using_speedangle', 
    'estimated_woba_using_speedangle', 
    'woba_value', 
    'woba_denom', 
    'babip_value', 
    'at_bat_number', 
    'pitch_number', 
    'home_score', 
    'away_score', 
    'bat_score', 
    'fld_score', 
    'post_away_score', 
    'post_home_score', 
    'post_bat_score', 
    'post_fld_score', 
    'if_fielding_alignment', 
    'of_fielding_alignment'
]

# %%
hr_df.drop(col, axis=1, inplace=True)

# %%
col=['pitch_type']
hr_df.dropna(subset=col, inplace=True)

# %%
len(hr_df.player_name.unique())
# Out:
# 759

# %%
hr_df.player_name.value_counts().index[hr_df.player_name.value_counts() == 1]
# Out:
# Index(['Jaime Garcia', 'Jon Singleton', 'Clayton Richard', 'Robbie Ray',
#        'Ramiro Pena', 'Michael Martinez', 'Gavin Cecchini', 'Daniel Norris',
#        'Charlie Culberson', 'Brennan Boesch',
#        ...
#        'Hector Gomez', 'Chris Rusin', 'Alex Verdugo', 'Collin Cowgill',
#        'Shane Victorino', 'Mat Latos', 'Jacob Hannemann', 'Chris Marrero',
#        'Pete Kozma', 'Alex Mejia'],
#       dtype='object', length=110)

# %%
hr_df['game_date'] = pd.to_datetime(hr_df['game_date'])

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16602 entries, 0 to 16625
# Data columns (total 36 columns):
# pitch_type            16602 non-null object
# game_date             16602 non-null datetime64[ns]
# release_speed         16600 non-null float64
# release_pos_x         16491 non-null float64
# release_pos_z         16491 non-null float64
# player_name           16602 non-null object
# batter                16602 non-null int64
# pitcher               16602 non-null int64
# zone                  16600 non-null float64
# p_throws              16602 non-null object
# home_team             16602 non-null object
# away_team             16602 non-null object
# bb_type               16602 non-null object
# game_year             16602 non-null int64
# pfx_x                 16600 non-null float64
# pfx_z                 16600 non-null float64
# plate_x               16600 non-null float64
# vx0                   16600 non-null float64
# vy0                   16600 non-null float64
# vz0                   16600 non-null float64
# ax                    16600 non-null float64
# ay                    16600 non-null float64
# az                    16600 non-null float64
# sz_top                16602 non-null float64
# sz_bot                16602 non-null float64
# hit_distance_sc       16182 non-null float64
# launch_speed          16602 non-null float64
# launch_angle          16602 non-null float64
# effective_speed       16272 non-null float64
# release_spin_rate     15591 non-null float64
# release_extension     16297 non-null float64
# game_pk               16602 non-null int64
# release_pos_y         16491 non-null float64
# iso_value             16602 non-null int64
# launch_speed_angle    16602 non-null int64
# pitch_name            16602 non-null object
# dtypes: datetime64[ns](1), float64(22), int64(6), object(7)
# memory usage: 4.7+ MB

# %%
hr_df.head()
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         CH 2017-06-10           84.5        -3.4020         6.4696
# 1         FF 2017-04-28           97.1        -2.8091         5.9279
# 2         CU 2015-06-23           86.7        -1.5647         5.3406
# 3         SL 2017-09-28           89.5         2.0682         6.1177
# 4         SL 2017-06-11           84.7        -1.9795         5.6860
#
#          player_name  batter  pitcher  zone p_throws       ...         \
# 0        Aaron Judge  592450   501957   4.0        R       ...
# 1        Aaron Judge  592450   592332   5.0        R       ...
# 2  Giancarlo Stanton  519317   593372   7.0        R       ...
# 3  Giancarlo Stanton  519317   571521   8.0        L       ...
# 4        Aaron Judge  592450   548337   5.0        R       ...
#
#   launch_speed launch_angle effective_speed  release_spin_rate  \
# 0        121.1       24.626          84.120             1682.0
# 1        119.4       16.541          96.019             2335.0
# 2        119.2       21.970          84.343                NaN
# 3        118.7       22.736          88.690             2173.0
# 4        118.6       28.419          84.757             2183.0
#
#    release_extension  game_pk  release_pos_y  iso_value  launch_speed_angle  \
# 0              6.342   491020        54.1561          3                   6
# 1              6.043   490431        54.4549          3                   6
# 2              5.035   414723        55.4629          3                   6
# 3              5.433   492474        55.0652          3                   6
# 4              6.153   491036        54.3442          3                   6
#
#         pitch_name
# 0         Changeup
# 1  4-Seam Fastball
# 2        Curveball
# 3           Slider
# 4           Slider
#
# [5 rows x 36 columns]

# %%
hr_df['launch_speed'].describe()
# Out:
# count    16602.000000
# mean       103.231159
# std          4.415599
# min         36.600000
# 25%        100.500000
# 50%        103.300000
# 75%        106.200000
# max        121.100000
# Name: launch_speed, dtype: float64

# %% [markdown]
# - CH : Changeup
# - CU : Curveball
# - EP : Eephus
# - FC : Cut Fastball (Cutter)
# - FF : Four-seam Fastball
# - FO : Pitch Out
# - FS : Sinking Fastball / Split-Fingered (Splitter)
# - FT : Two-seam Fastball
# - KC : Knuckle-curve
# - KN : Knuckleball
# - SC : Screwball
# - SI : Sinker
# - SL : Slider

# %%
hr_df[(hr_df.pitch_type == 'FF') & (hr_df.pitcher == 517414)]
# Out:
#       pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1066          FF 2015-05-09           94.3        -0.7633         6.2443
# 2828          FF 2016-07-01           93.4        -0.7002         6.4708
# 3253          FF 2015-04-15           94.7        -1.9226         6.6718
# 3960          FF 2016-05-31           92.5        -2.7624         6.2747
# 5812          FF 2016-08-02           92.4        -1.2452         6.2537
# 9267          FF 2017-04-04            NaN            NaN            NaN
# 12014         FF 2017-06-09           94.3        -1.4991         6.1734
#
#             player_name  batter  pitcher  zone p_throws       ...         \
# 1066       Justin Upton  457708   517414   8.0        R       ...
# 2828     Jarrett Parker  592620   517414  13.0        R       ...
# 3253       Justin Upton  457708   517414   2.0        R       ...
# 3960      Luis Valbuena  472528   517414   4.0        R       ...
# 5812       Jayson Werth  150029   517414   4.0        R       ...
# 9267   Brandon Crawford  543063   517414   NaN        R       ...
# 12014      Hernan Perez  541650   517414   4.0        R       ...
#
#       launch_speed launch_angle effective_speed  release_spin_rate  \
# 1066         109.7      19.0770          94.305             2109.0
# 2828         107.3      32.8450          94.110             2114.0
# 3253         106.9      22.2869             NaN                NaN
# 3960         106.3      27.2920          93.546             2360.0
# 5812         104.9      19.4060          92.230             2275.0
# 9267         102.8      30.1990             NaN                NaN
# 12014        100.9      35.2270          94.207             2270.0
#
#        release_extension  game_pk  release_pos_y  iso_value  \
# 1066               6.064   414106        54.4355          3
# 2828               6.337   448070        54.1639          3
# 3253                 NaN   413769        54.2295          3
# 3960               6.383   447643        54.1182          3
# 5812               6.004   448460        54.4976          3
# 9267                 NaN   490118            NaN          3
# 12014              5.966   491013        54.5331          3
#
#        launch_speed_angle       pitch_name
# 1066                    6  4-Seam Fastball
# 2828                    6  4-Seam Fastball
# 3253                    6  4-Seam Fastball
# 3960                    6  4-Seam Fastball
# 5812                    6  4-Seam Fastball
# 9267                    6  4-Seam Fastball
# 12014                   5  4-Seam Fastball
#
# [7 rows x 36 columns]

# %%
pitch_avg = hr_df.groupby(['pitcher', 'pitch_type'])[['release_speed', 
                                                      'release_pos_x', 
                                                      'release_pos_y',
                                                      'release_pos_z',
                                                      'release_spin_rate',
                                                      'release_extension',
                                                      'pfx_x',
                                                      'pfx_z',
                                                      'plate_x',
                                                      'vx0',
                                                      'vy0',
                                                      'vz0',
                                                      'ax',
                                                      'ay',
                                                      'az',
                                                      'effective_speed']].mean()

# %%
pitch_avg.reset_index(inplace=True)

# %%
pitch_avg[(pitch_avg['pitcher']==112526)]['release_speed']
# Out:
# 0    81.540000
# 1    91.388235
# 2    87.585106
# 3    81.700000
# Name: release_speed, dtype: float64

# %%
pitch_avg.head()
# Out:
#    pitcher pitch_type  release_speed  release_pos_x  release_pos_y  \
# 0   112526         CH      81.540000      -1.391520      55.250980
# 1   112526         FF      91.388235      -0.988865      55.251547
# 2   112526         FT      87.585106      -1.425957      55.216726
# 3   112526         SL      81.700000      -1.545200      55.437425
# 4   115629         CH      84.300000      -1.830700      54.319700
#
#    release_pos_z  release_spin_rate  release_extension     pfx_x     pfx_z  \
# 0       5.754080        1637.600000           5.249200 -1.142933  0.835700
# 1       5.992818        2276.562500           5.257500 -0.717337  1.424175
# 2       5.713583        2109.446809           5.283426 -1.339216  0.963503
# 3       5.835250        2309.000000           5.061250  0.077197  0.502796
# 4       6.365500        1669.000000           6.148000 -1.051283  1.365300
#
#     plate_x       vx0         vy0       vz0         ax         ay         az  \
# 0 -0.223840  4.451960 -118.456220 -2.985940 -10.667300  22.154580 -25.151200
# 1 -0.022853  3.560453 -132.811671 -4.633582  -8.148265  29.473624 -16.233365
# 2 -0.173119  5.304594 -127.276523 -3.549502 -14.556315  26.805947 -22.843936
# 3  0.172225  3.291075 -118.803012 -1.377837   1.219612  21.471113 -28.542300
# 4 -0.379000  4.877000 -122.597000 -4.700000 -10.074000  24.338000 -19.731000
#
#    effective_speed
# 0        79.894600
# 1        89.426625
# 2        85.687319
# 3        79.894375
# 4        83.946000

# %%
def pitcher_avg(pitch, col):
    return float(pitch_avg[(pitch_avg['pitcher']==pitch.pitcher) & 
                           (pitch_avg['pitch_type']==pitch.pitch_type)][col])

# %%
np.isnan(hr_df.loc[9267, 'release_speed'])
# Out:
# True

# %%
float(pitcher_avg(hr_df.loc[9267, :], 'release_speed'))
# Out:
# 93.59999999999998

# %%
hr_df['release_speed'] = hr_df.apply(lambda x: pitcher_avg(x, 'release_speed') 
                                     if np.isnan(x['release_speed']) 
                                     else x['release_speed'],1)

# %%
hr_df[(hr_df.pitch_type == 'FF') & (hr_df.pitcher == 517414)]
# Out:
#       pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1066          FF 2015-05-09           94.3        -0.7633         6.2443
# 2828          FF 2016-07-01           93.4        -0.7002         6.4708
# 3253          FF 2015-04-15           94.7        -1.9226         6.6718
# 3960          FF 2016-05-31           92.5        -2.7624         6.2747
# 5812          FF 2016-08-02           92.4        -1.2452         6.2537
# 9267          FF 2017-04-04           93.6            NaN            NaN
# 12014         FF 2017-06-09           94.3        -1.4991         6.1734
#
#             player_name  batter  pitcher  zone p_throws       ...         \
# 1066       Justin Upton  457708   517414   8.0        R       ...
# 2828     Jarrett Parker  592620   517414  13.0        R       ...
# 3253       Justin Upton  457708   517414   2.0        R       ...
# 3960      Luis Valbuena  472528   517414   4.0        R       ...
# 5812       Jayson Werth  150029   517414   4.0        R       ...
# 9267   Brandon Crawford  543063   517414   NaN        R       ...
# 12014      Hernan Perez  541650   517414   4.0        R       ...
#
#       launch_speed launch_angle effective_speed  release_spin_rate  \
# 1066         109.7      19.0770          94.305             2109.0
# 2828         107.3      32.8450          94.110             2114.0
# 3253         106.9      22.2869             NaN                NaN
# 3960         106.3      27.2920          93.546             2360.0
# 5812         104.9      19.4060          92.230             2275.0
# 9267         102.8      30.1990             NaN                NaN
# 12014        100.9      35.2270          94.207             2270.0
#
#        release_extension  game_pk  release_pos_y  iso_value  \
# 1066               6.064   414106        54.4355          3
# 2828               6.337   448070        54.1639          3
# 3253                 NaN   413769        54.2295          3
# 3960               6.383   447643        54.1182          3
# 5812               6.004   448460        54.4976          3
# 9267                 NaN   490118            NaN          3
# 12014              5.966   491013        54.5331          3
#
#        launch_speed_angle       pitch_name
# 1066                    6  4-Seam Fastball
# 2828                    6  4-Seam Fastball
# 3253                    6  4-Seam Fastball
# 3960                    6  4-Seam Fastball
# 5812                    6  4-Seam Fastball
# 9267                    6  4-Seam Fastball
# 12014                   5  4-Seam Fastball
#
# [7 rows x 36 columns]

# %%
hr_df['release_pos_x'] = hr_df.apply(lambda x: pitcher_avg(x, 'release_pos_x') 
                                     if np.isnan(x['release_pos_x']) 
                                     else x['release_pos_x'],1)

# %%
hr_df[hr_df['release_pos_x'].isnull()]
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 7232         CH 2016-09-27           83.2            NaN            NaN
# 8849         FF 2015-04-06           91.5            NaN            NaN
# 8947         CH 2016-06-11           86.9            NaN            NaN
# 8954         CH 2015-04-30           81.5            NaN            NaN
# 8956         CU 2015-05-13           80.4            NaN            NaN
# 8976         CU 2015-06-17           70.3            NaN            NaN
#
#             player_name  batter  pitcher  zone p_throws       ...         \
# 7232       Hunter Pence  452254   608566   7.0        R       ...
# 8849          Alex Rios  425567   475138  13.0        R       ...
# 8947  Edwin Encarnacion  429665   488846   7.0        L       ...
# 8954          Darin Ruf  573131   608641  14.0        L       ...
# 8956       Buster Posey  457763   465679   2.0        R       ...
# 8976       Todd Frazier  453943   465657  12.0        R       ...
#
#      launch_speed launch_angle effective_speed  release_spin_rate  \
# 7232        104.0         24.0             NaN                NaN
# 8849        103.0         30.0             NaN                NaN
# 8947        103.0         30.0             NaN                NaN
# 8954        103.0         30.0             NaN                NaN
# 8956        103.0         30.0             NaN                NaN
# 8976        103.0         30.0             NaN                NaN
#
#       release_extension  game_pk  release_pos_y  iso_value  \
# 7232                NaN   449217            NaN          3
# 8849                NaN   413653            NaN          3
# 8947                NaN   447787            NaN          3
# 8954                NaN   413978            NaN          3
# 8956                NaN   414160            NaN          3
# 8976                NaN   414632            NaN          3
#
#       launch_speed_angle       pitch_name
# 7232                   6         Changeup
# 8849                   6  4-Seam Fastball
# 8947                   6         Changeup
# 8954                   6         Changeup
# 8956                   6        Curveball
# 8976                   6        Curveball
#
# [6 rows x 36 columns]

# %%
pitch_avg[pitch_avg['pitcher'] == 608566]
# Out:
#       pitcher pitch_type  release_speed  release_pos_x  release_pos_y  \
# 2834   608566         CH         83.200            NaN            NaN
# 2835   608566         CU         81.700      -2.646600       55.79980
# 2836   608566         FF         94.660      -2.742973       55.28748
# 2837   608566         FT         92.025      -3.023667       54.95880
# 2838   608566         SL         87.640      -2.927920       55.50422
#
#       release_pos_z  release_spin_rate  release_extension     pfx_x     pfx_z  \
# 2834            NaN                NaN                NaN -1.286475  0.436500
# 2835       6.147950        2784.500000           4.700000  0.518000 -0.560350
# 2836       6.117993        2153.066667           5.212333 -0.335233  1.369593
# 2837       6.016267        2142.000000           5.543667 -1.348821  1.247108
# 2838       6.229860        1999.000000           4.995000  0.168380  0.938080
#
#        plate_x       vx0         vy0       vz0         ax         ay  \
# 2834 -0.483000  7.225000 -120.863000 -4.047000 -12.354000  22.388000
# 2835  0.394900  5.725000 -118.468550 -1.367000   3.303900  22.653950
# 2836 -0.129200  7.347820 -137.265560 -6.130647  -5.505493  26.682973
# 2837 -0.178925  9.639075 -133.402525 -5.359075 -17.336500  26.526925
# 2838 -0.146400  6.205620 -127.144820 -4.185600   0.693560  23.252640
#
#              az  effective_speed
# 2834 -29.653000              NaN
# 2835 -37.267500        79.138000
# 2836 -14.390487        92.984000
# 2837 -17.521050        90.827667
# 2838 -21.751520        85.753600

# %%
hr_df['release_pos_z'] = hr_df.apply(lambda x: pitcher_avg(x, 'release_pos_z') 
                                     if np.isnan(x['release_pos_z']) 
                                     else x['release_pos_z'],1)

# %%
hr_df['release_pos_y'] = hr_df.apply(lambda x: pitcher_avg(x, 'release_pos_y') 
                                     if np.isnan(x['release_pos_y']) 
                                     else x['release_pos_y'],1)

# %%
hr_df['release_spin_rate'] = hr_df.apply(lambda x: pitcher_avg(x, 'release_spin_rate') 
                                     if np.isnan(x['release_spin_rate']) 
                                     else x['release_spin_rate'],1)

# %%
hr_df['release_extension'] = hr_df.apply(lambda x: pitcher_avg(x, 'release_extension') 
                                     if np.isnan(x['release_extension']) 
                                     else x['release_extension'],1)

# %%
hr_df['pfx_x'] = hr_df.apply(lambda x: pitcher_avg(x, 'pfx_x') 
                                     if np.isnan(x['pfx_x']) 
                                     else x['pfx_x'],1)

# %%
hr_df['pfx_z'] = hr_df.apply(lambda x: pitcher_avg(x, 'pfx_z') 
                                     if np.isnan(x['pfx_z']) 
                                     else x['pfx_z'],1)

# %%
hr_df['plate_x'] = hr_df.apply(lambda x: pitcher_avg(x, 'plate_x') 
                                     if np.isnan(x['plate_x']) 
                                     else x['plate_x'],1)

# %%
hr_df['vy0'] = hr_df.apply(lambda x: pitcher_avg(x, 'vx0') 
                                     if np.isnan(x['vy0']) 
                                     else x['vy0'],1)

# %%
hr_df['vz0'] = hr_df.apply(lambda x: pitcher_avg(x, 'vz0') 
                                     if np.isnan(x['vz0']) 
                                     else x['vz0'],1)

# %%
hr_df['ax'] = hr_df.apply(lambda x: pitcher_avg(x, 'ax') 
                                     if np.isnan(x['ax']) 
                                     else x['ax'],1)

# %%
hr_df['ay'] = hr_df.apply(lambda x: pitcher_avg(x, 'ay') 
                                     if np.isnan(x['ay']) 
                                     else x['ay'],1)

# %%
hr_df['az'] = hr_df.apply(lambda x: pitcher_avg(x, 'az') 
                                     if np.isnan(x['az']) 
                                     else x['az'],1)

# %%
hr_df['effective_speed'] = hr_df.apply(lambda x: pitcher_avg(x, 'effective_speed') 
                                     if np.isnan(x['effective_speed']) 
                                     else x['effective_speed'],1)

# %%
pitch_avg.head()
# Out:
#    pitcher pitch_type  release_speed  release_pos_x  release_pos_y  \
# 0   112526         CH      81.540000      -1.391520      55.250980
# 1   112526         FF      91.388235      -0.988865      55.251547
# 2   112526         FT      87.585106      -1.425957      55.216726
# 3   112526         SL      81.700000      -1.545200      55.437425
# 4   115629         CH      84.300000      -1.830700      54.319700
#
#    release_pos_z  release_spin_rate  release_extension     pfx_x     pfx_z  \
# 0       5.754080        1637.600000           5.249200 -1.142933  0.835700
# 1       5.992818        2276.562500           5.257500 -0.717337  1.424175
# 2       5.713583        2109.446809           5.283426 -1.339216  0.963503
# 3       5.835250        2309.000000           5.061250  0.077197  0.502796
# 4       6.365500        1669.000000           6.148000 -1.051283  1.365300
#
#     plate_x       vx0         vy0       vz0         ax         ay         az  \
# 0 -0.223840  4.451960 -118.456220 -2.985940 -10.667300  22.154580 -25.151200
# 1 -0.022853  3.560453 -132.811671 -4.633582  -8.148265  29.473624 -16.233365
# 2 -0.173119  5.304594 -127.276523 -3.549502 -14.556315  26.805947 -22.843936
# 3  0.172225  3.291075 -118.803012 -1.377837   1.219612  21.471113 -28.542300
# 4 -0.379000  4.877000 -122.597000 -4.700000 -10.074000  24.338000 -19.731000
#
#    effective_speed
# 0        79.894600
# 1        89.426625
# 2        85.687319
# 3        79.894375
# 4        83.946000

# %%
hr_df[hr_df['zone'].isnull()][['pitch_type']]
# Out:
#      pitch_type
# 9267         FF
# 9357         CH

# %%
hr_df[(hr_df['pitcher'] == 517414) & (hr_df['pitch_type'] == 'FF')]
# Out:
#       pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1066          FF 2015-05-09           94.3      -0.763300       6.244300
# 2828          FF 2016-07-01           93.4      -0.700200       6.470800
# 3253          FF 2015-04-15           94.7      -1.922600       6.671800
# 3960          FF 2016-05-31           92.5      -2.762400       6.274700
# 5812          FF 2016-08-02           92.4      -1.245200       6.253700
# 9267          FF 2017-04-04           93.6      -1.482133       6.348117
# 12014         FF 2017-06-09           94.3      -1.499100       6.173400
#
#             player_name  batter  pitcher  zone p_throws       ...         \
# 1066       Justin Upton  457708   517414   8.0        R       ...
# 2828     Jarrett Parker  592620   517414  13.0        R       ...
# 3253       Justin Upton  457708   517414   2.0        R       ...
# 3960      Luis Valbuena  472528   517414   4.0        R       ...
# 5812       Jayson Werth  150029   517414   4.0        R       ...
# 9267   Brandon Crawford  543063   517414   NaN        R       ...
# 12014      Hernan Perez  541650   517414   4.0        R       ...
#
#       launch_speed launch_angle effective_speed  release_spin_rate  \
# 1066         109.7      19.0770         94.3050             2109.0
# 2828         107.3      32.8450         94.1100             2114.0
# 3253         106.9      22.2869         93.6796             2225.6
# 3960         106.3      27.2920         93.5460             2360.0
# 5812         104.9      19.4060         92.2300             2275.0
# 9267         102.8      30.1990         93.6796             2225.6
# 12014        100.9      35.2270         94.2070             2270.0
#
#        release_extension  game_pk  release_pos_y  iso_value  \
# 1066              6.0640   414106      54.435500          3
# 2828              6.3370   448070      54.163900          3
# 3253              6.1508   413769      54.229500          3
# 3960              6.3830   447643      54.118200          3
# 5812              6.0040   448460      54.497600          3
# 9267              6.1508   490118      54.329633          3
# 12014             5.9660   491013      54.533100          3
#
#        launch_speed_angle       pitch_name
# 1066                    6  4-Seam Fastball
# 2828                    6  4-Seam Fastball
# 3253                    6  4-Seam Fastball
# 3960                    6  4-Seam Fastball
# 5812                    6  4-Seam Fastball
# 9267                    6  4-Seam Fastball
# 12014                   5  4-Seam Fastball
#
# [7 rows x 36 columns]

# %%
hr_df.reset_index(inplace=True)

# %%
hr_df[(hr_df['pitcher'] == 517414) & (hr_df['pitch_type'] == 'FF')]
# Out:
#        index pitch_type  game_date  release_speed  release_pos_x  \
# 1066    1066         FF 2015-05-09           94.3      -0.763300
# 2827    2828         FF 2016-07-01           93.4      -0.700200
# 3252    3253         FF 2015-04-15           94.7      -1.922600
# 3959    3960         FF 2016-05-31           92.5      -2.762400
# 5809    5812         FF 2016-08-02           92.4      -1.245200
# 9248    9267         FF 2017-04-04           93.6      -1.482133
# 11993  12014         FF 2017-06-09           94.3      -1.499100
#
#        release_pos_z       player_name  batter  pitcher  zone  \
# 1066        6.244300      Justin Upton  457708   517414   8.0
# 2827        6.470800    Jarrett Parker  592620   517414  13.0
# 3252        6.671800      Justin Upton  457708   517414   2.0
# 3959        6.274700     Luis Valbuena  472528   517414   4.0
# 5809        6.253700      Jayson Werth  150029   517414   4.0
# 9248        6.348117  Brandon Crawford  543063   517414   NaN
# 11993       6.173400      Hernan Perez  541650   517414   4.0
#
#             ...        launch_speed launch_angle effective_speed  \
# 1066        ...               109.7      19.0770         94.3050
# 2827        ...               107.3      32.8450         94.1100
# 3252        ...               106.9      22.2869         93.6796
# 3959        ...               106.3      27.2920         93.5460
# 5809        ...               104.9      19.4060         92.2300
# 9248        ...               102.8      30.1990         93.6796
# 11993       ...               100.9      35.2270         94.2070
#
#       release_spin_rate  release_extension  game_pk  release_pos_y  iso_value  \
# 1066             2109.0             6.0640   414106      54.435500          3
# 2827             2114.0             6.3370   448070      54.163900          3
# 3252             2225.6             6.1508   413769      54.229500          3
# 3959             2360.0             6.3830   447643      54.118200          3
# 5809             2275.0             6.0040   448460      54.497600          3
# 9248             2225.6             6.1508   490118      54.329633          3
# 11993            2270.0             5.9660   491013      54.533100          3
#
#        launch_speed_angle       pitch_name
# 1066                    6  4-Seam Fastball
# 2827                    6  4-Seam Fastball
# 3252                    6  4-Seam Fastball
# 3959                    6  4-Seam Fastball
# 5809                    6  4-Seam Fastball
# 9248                    6  4-Seam Fastball
# 11993                   5  4-Seam Fastball
#
# [7 rows x 37 columns]

# %%
hr_df['zone'].iloc[9248] = 4
# Out:
# /Users/nelson/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
hr_df['zone'].iloc[9248]
# Out:
# 4.0

# %%
hr_df[(hr_df['pitcher'] == 573186) & (hr_df['pitch_type'] == 'CH')]
# Out:
#        index pitch_type  game_date  release_speed  release_pos_x  \
# 7295    7306         CH 2016-06-19         85.500      -1.055900
# 9338    9357         CH 2017-06-22         83.725      -1.016825
# 10677  10697         CH 2016-05-28         83.900      -0.891100
# 14968  14992         CH 2016-04-19         83.300      -0.949700
# 15655  15679         CH 2015-09-30         82.200      -1.170600
#
#        release_pos_z        player_name  batter  pitcher  zone     ...      \
# 7295          5.5616       Matt Wieters  446308   573186   4.0     ...
# 9338          5.5545  Robinson Chirinos  455139   573186   NaN     ...
# 10677         5.3561        Travis Shaw  543768   573186   4.0     ...
# 14968         5.7024       Matt Wieters  446308   573186   5.0     ...
# 15655         5.5979       Steve Pearce  456665   573186   1.0     ...
#
#       launch_speed launch_angle effective_speed release_spin_rate  \
# 7295         104.0       24.000          82.673            1474.5
# 9338         102.8       30.199          82.673            1474.5
# 10677        101.9       35.761          83.308            1384.0
# 14968         97.6       27.999          82.038            1565.0
# 15655         96.1       34.612          82.673            1474.5
#
#        release_extension  game_pk  release_pos_y  iso_value  \
# 7295              5.6465   447910      54.940600          3
# 9338              5.6465   491197      54.950825          3
# 10677             5.8070   447595      54.693000          3
# 14968             5.4860   447072      55.012600          3
# 15655             5.6465   416021      55.157100          3
#
#        launch_speed_angle  pitch_name
# 7295                    6    Changeup
# 9338                    6    Changeup
# 10677                   6    Changeup
# 14968                   6    Changeup
# 15655                   3    Changeup
#
# [5 rows x 37 columns]

# %%
hr_df['zone'].iloc[9338] = 4

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16602 entries, 0 to 16601
# Data columns (total 37 columns):
# index                 16602 non-null int64
# pitch_type            16602 non-null object
# game_date             16602 non-null datetime64[ns]
# release_speed         16602 non-null float64
# release_pos_x         16596 non-null float64
# release_pos_z         16596 non-null float64
# player_name           16602 non-null object
# batter                16602 non-null int64
# pitcher               16602 non-null int64
# zone                  16602 non-null float64
# p_throws              16602 non-null object
# home_team             16602 non-null object
# away_team             16602 non-null object
# bb_type               16602 non-null object
# game_year             16602 non-null int64
# pfx_x                 16602 non-null float64
# pfx_z                 16602 non-null float64
# plate_x               16602 non-null float64
# vx0                   16600 non-null float64
# vy0                   16602 non-null float64
# vz0                   16602 non-null float64
# ax                    16602 non-null float64
# ay                    16602 non-null float64
# az                    16602 non-null float64
# sz_top                16602 non-null float64
# sz_bot                16602 non-null float64
# hit_distance_sc       16182 non-null float64
# launch_speed          16602 non-null float64
# launch_angle          16602 non-null float64
# effective_speed       16585 non-null float64
# release_spin_rate     16475 non-null float64
# release_extension     16586 non-null float64
# game_pk               16602 non-null int64
# release_pos_y         16596 non-null float64
# iso_value             16602 non-null int64
# launch_speed_angle    16602 non-null int64
# pitch_name            16602 non-null object
# dtypes: datetime64[ns](1), float64(22), int64(7), object(7)
# memory usage: 4.7+ MB

# %%
batter_distance = hr_df.groupby(['pitch_type', 'batter', 'bb_type']).mean()[['hit_distance_sc']]

# %%
batter_distance.reset_index(inplace=True)

# %%
batter_distance.head()
# Out:
#   pitch_type  batter     bb_type  hit_distance_sc
# 0         CH  116338    fly_ball       391.666667
# 1         CH  120074    fly_ball       379.000000
# 2         CH  120074  line_drive       413.666667
# 3         CH  121347    fly_ball       385.500000
# 4         CH  121347  line_drive       412.000000

# %%
def pitcher_avg(pitch, col):
    return float(pitch_avg[(pitch_avg['pitcher']==pitch.pitcher) & 
                           (pitch_avg['pitch_type']==pitch.pitch_type)][col])

# %%
def batter_avg_distance(pitch, col):
    return float(batter_distance[(batter_distance['batter']==pitch.batter) &
                                 (batter_distance['pitch_type']==pitch.pitch_type) &
                                 (batter_distance['bb_type']==pitch.bb_type)][col])

# %%
hr_df['hit_distance_sc'] = hr_df.apply(lambda x: batter_avg_distance(x, 'hit_distance_sc') 
                                       if np.isnan(x['hit_distance_sc']) 
                                       else x['hit_distance_sc'],1)

# %%
hr_df.dropna(inplace=True)

# %%
hr_df.to_csv('../data/clean_hr.csv')

# %% [markdown]
# ### Baseballs

# %%
baseballs_df.head()
# Out:
#   BALL CODE       Year   SN  Weight (oz)  Circumference (in)  AVG Seam Height  \
# 0  MSCC0051 2014-05-15  731        5.135                9.13          0.03587
# 1  MSCC0032 2014-07-15  228        5.149                9.09          0.04403
# 2  MSCC0030 2015-04-15  196        5.143                9.06          0.03726
# 3  MSCC0045 2015-04-15  351        5.109                9.09          0.04574
# 4  MSCC0048 2015-04-15  499        5.192                9.19          0.04862
#
#    STD of Seam Height  AVG CCOR  AVG DS  # OF GOOD SHOTS BEFORE DAMAGE
# 0             0.01049     0.491   12133                            NaN
# 1             0.01781     0.489   12468                            NaN
# 2             0.00640     0.489   12518                            NaN
# 3             0.01216     0.496   13442                            NaN
# 4             0.00828     0.474   12394                            5.0

# %%
baseballs_df.columns = [i.lower().replace(' ', '_') for i in baseballs_df.columns]

# %%
baseballs_df.head()
# Out:
#   ball_code       year   sn  weight_(oz)  circumference_(in)  avg_seam_height  \
# 0  MSCC0051 2014-05-15  731        5.135                9.13          0.03587
# 1  MSCC0032 2014-07-15  228        5.149                9.09          0.04403
# 2  MSCC0030 2015-04-15  196        5.143                9.06          0.03726
# 3  MSCC0045 2015-04-15  351        5.109                9.09          0.04574
# 4  MSCC0048 2015-04-15  499        5.192                9.19          0.04862
#
#    std_of_seam_height  avg_ccor  avg_ds  #_of_good_shots_before_damage
# 0             0.01049     0.491   12133                            NaN
# 1             0.01781     0.489   12468                            NaN
# 2             0.00640     0.489   12518                            NaN
# 3             0.01216     0.496   13442                            NaN
# 4             0.00828     0.474   12394                            5.0

# %%
col = [
    'ball_code',
    '#_of_good_shots_before_damage',
    'sn'
]

baseballs_df.drop(col, axis=1, inplace=True)

# %%
baseballs_df.head()
# Out:
#         year  weight_(oz)  circumference_(in)  avg_seam_height  \
# 0 2014-05-15        5.135                9.13          0.03587
# 1 2014-07-15        5.149                9.09          0.04403
# 2 2015-04-15        5.143                9.06          0.03726
# 3 2015-04-15        5.109                9.09          0.04574
# 4 2015-04-15        5.192                9.19          0.04862
#
#    std_of_seam_height  avg_ccor  avg_ds
# 0             0.01049     0.491   12133
# 1             0.01781     0.489   12468
# 2             0.00640     0.489   12518
# 3             0.01216     0.496   13442
# 4             0.00828     0.474   12394

# %%
baseballs_df['year'] = pd.to_datetime(baseballs_df['year'])

# %%
baseballs_df.set_index('year', inplace=True)

# %%
baseballs_df.head()
# Out:
#             weight_(oz)  circumference_(in)  avg_seam_height  \
# year
# 2014-05-15        5.135                9.13          0.03587
# 2014-07-15        5.149                9.09          0.04403
# 2015-04-15        5.143                9.06          0.03726
# 2015-04-15        5.109                9.09          0.04574
# 2015-04-15        5.192                9.19          0.04862
#
#             std_of_seam_height  avg_ccor  avg_ds
# year
# 2014-05-15             0.01049     0.491   12133
# 2014-07-15             0.01781     0.489   12468
# 2015-04-15             0.00640     0.489   12518
# 2015-04-15             0.01216     0.496   13442
# 2015-04-15             0.00828     0.474   12394

# %%
bb_15 = baseballs_df['2015'][['weight_(oz)',
                      'circumference_(in)',
                      'avg_seam_height',
                      'std_of_seam_height',
                      'avg_ccor',
                      'avg_ds']].mean().to_frame().T
bb_15['year'] = 2015
bb_15
# Out:
#    weight_(oz)  circumference_(in)  avg_seam_height  std_of_seam_height  \
# 0     5.120125            9.107917         0.040502            0.011194
#
#    avg_ccor     avg_ds  year
# 0  0.491333  12740.875  2015

# %%
bb_16 = baseballs_df['2016'][['weight_(oz)',
                      'circumference_(in)',
                      'avg_seam_height',
                      'std_of_seam_height',
                      'avg_ccor',
                      'avg_ds']].mean().to_frame().T
bb_16['year'] = 2016
bb_16
# Out:
#    weight_(oz)  circumference_(in)  avg_seam_height  std_of_seam_height  \
# 0       5.1225               9.079         0.038432            0.010468
#
#    avg_ccor   avg_ds  year
# 0    0.4941  12926.4  2016

# %%
mlb_baseballs = bb_15.append(bb_16).reset_index()
mlb_baseballs.drop('index', axis=1, inplace=True)
mlb_baseballs.drop('std_of_seam_height', axis=1, inplace=True)
mlb_baseballs
# Out:
#    weight_(oz)  circumference_(in)  avg_seam_height  avg_ccor     avg_ds  year
# 0     5.120125            9.107917         0.040502  0.491333  12740.875  2015
# 1     5.122500            9.079000         0.038432  0.494100  12926.400  2016

# %%
bb_17 = pd.DataFrame(
    [[.494,.03843,9.08,5.122,12926,2017]], columns=['avg_ccor', 
                                                   'avg_seam_height',
                                                   'circumference_(in)',
                                                   'weight_(oz)',
                                                   'avg_ds',
                                                   'year']
)
bb_17
# Out:
#    avg_ccor  avg_seam_height  circumference_(in)  weight_(oz)  avg_ds  year
# 0     0.494          0.03843                9.08        5.122   12926  2017

# %%
mlb_baseballs = mlb_baseballs.append(bb_17, sort=False).reset_index().drop('index', axis=1)

# %%
mlb_baseballs
# Out:
#    weight_(oz)  circumference_(in)  avg_seam_height  avg_ccor     avg_ds  year
# 0     5.120125            9.107917         0.040502  0.491333  12740.875  2015
# 1     5.122500            9.079000         0.038432  0.494100  12926.400  2016
# 2     5.122000            9.080000         0.038430  0.494000  12926.000  2017

# %% [markdown]
# ### Player Personal Stats

# %%
url = "https://baseballsavant.mlb.com/savant-player/j-d-martinez-502110?stats=career-r-hitting-mlb"
res =  requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
jd_martinez_player = soup.find('section', {'id':'player'})

# %%
jd_martinez_player
# Out:
# <section id="player">
# <div class="container white-bg padding">
# <style>
#           .player-background::after {
#             content: '';
#               background: url('https://www.mlbstatic.com/team-logos/111.svg') center center/10% no-repeat;
#             // background: url('http://mlb.mlb.com/images/players/action_shots/502110.jpg') center center/100% no-repeat;
#             // background-position: 20% 0;
#             opacity: 0.2;
#             top: 0;
#             left: 0;
#             bottom: 0;
#             right: 0;
#             position: absolute;
#             z-index: 0;
#           }
#
#           @media (max-width: 768px) {
#               .player-background::after {
#               content: '';
#               background: url('https://www.mlbstatic.com/team-logos/111.svg') center center/15% no-repeat;
#               opacity: 0.2;
#               top: 0;
#               left: 0;
#               bottom: 0;
#               right: 0;
#               position: absolute;
#               z-index: 0;
#             }
#           }
#
#           @media (max-width: 400px) {
#               .player-background::after {
#               content: '';
#               background: url('https://www.mlbstatic.com/team-logos/111.svg') center center/22% no-repeat;
#               opacity: 0.2;
#               top: 0;
#               left: 0;
#               bottom: 0;
#               right: 0;
#               position: absolute;
#               z-index: 0;
#             }
#           }
#         </style>
# <section id="player-info-new">
# <div class="player-avatar-data">
# <div class="player-background">
# <div class="box15">
# <img alt="J.D. Martinez" class="player-header--headshot" onerror="this.onerror=null;this.src='https://content.mlb.com/images/headshots/current/60x60/generic.png';" src="https://securea.mlb.com/mlb/images/players/head_shot/502110.jpg" srcset="
#                     https://securea.mlb.com/mlb/images/players/head_shot/502110.jpg 1x,
#                     https://securea.mlb.com/mlb/images/players/head_shot/502110@2x.jpg 2x,
#                     https://securea.mlb.com/mlb/images/players/head_shot/502110@3x.jpg 3x"/>
# </div>
# <div class="box40">
# <div class="player-name" style="float: left;">
#                     J.D. Martinez #28
#                 </div>
# <div id="player-award-items" style="position: relative; z-index: 2; padding-top: 5px;">
# <span class="player-award-item">2 x  AL All-Star</span><span class="player-award-badge-comma">,</span>
# <span class="player-award-item"> AL Silver Slugger</span><span class="player-award-badge-comma">,</span>
# </div>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div><br/>
# <div id="mechanics">
# <div class="box33">
# <div class="box-title">HT</div>
# <div class="box-text">6' 3"</div>
# </div>
# <div class="box33">
# <div class="box-title">WT</div>
# <div class="box-text">220</div>
# </div>
# <div class="box34">
# <div class="box-title">AGE</div>
# <div class="box-text">31</div>
# </div>
# <div class="box33">
# <div class="box-title">POS</div>
# <div class="box-text">LF</div>
# </div>
# <div class="box33">
# <div class="box-title">BAT</div>
# <div class="box-text">R</div>
# </div>
# <div class="box34">
# <div class="box-title">THROW</div>
# <div class="box-text">R</div>
# </div>
# </div>
# <div id="bio">
# <div class="box33">
# <div class="box-title">BORN</div>
# <div class="box-text">
#                 Aug 21, 1987
#               </div>
# </div>
# <div class="box67">
# <div class="box-title">FROM</div>
# <div class="box-text">Miami, FL USA </div>
# </div>
# <div class="box33">
# <div class="box-title">DEBUT</div>
# <div class="box-text">
#                       Jul 30, 2011
#                        </div>
# </div>
# <div class="box33">
# <div class="box-title">DRAFTED</div>
# <div class="box-text">2009 </div>
# </div>
# <div class="box34">
# <div class="box-title">ACTIVE</div>
# <div class="box-text">YES</div>
# </div>
# </div>
# <div style="clear: both;"></div>
# </section>
# <section id="stats-section">
# <h2><span>Stats</span></h2>
# <div class="divider" id="stats"></div>
# <div id="top-stats">
# <div class="non-mobile">
# <table>
# <thead>
# <tr class="tr-component-row">
# <th class="th-component-header"></th>
# <th class="th-component-header">AB</th>
# <th class="th-component-header">R</th>
# <th class="th-component-header">H</th>
# <th class="th-component-header">HR</th>
# <th class="th-component-header">RBI</th>
# <th class="th-component-header">SB</th>
# <th class="th-component-header">AVG</th>
# <th class="th-component-header">OBP</th>
# <th class="th-component-header">SLG</th>
# <th class="th-component-header">OPS</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="tr-data align-left"><span>2018</span></td>
# <td class="tr-data"><span>569</span></td>
# <td class="tr-data"><span>111</span></td>
# <td class="tr-data"><span>188</span></td>
# <td class="tr-data"><span>43</span></td>
# <td class="tr-data"><span>130</span></td>
# <td class="tr-data"><span>6</span></td>
# <td class="tr-data"><span>.330</span></td>
# <td class="tr-data"><span>.402</span></td>
# <td class="tr-data"><span>.629</span></td>
# <td class="tr-data"><span>1.031</span></td>
# </tr>
# <tr>
# <td class="tr-data align-left"><span>8 Seasons</span></td>
# <td class="tr-data"><span>3397</span></td>
# <td class="tr-data"><span>502</span></td>
# <td class="tr-data"><span>993</span></td>
# <td class="tr-data"><span>195</span></td>
# <td class="tr-data"><span>606</span></td>
# <td class="tr-data"><span>22</span></td>
# <td class="tr-data"><span>.292</span></td>
# <td class="tr-data"><span>.353</span></td>
# <td class="tr-data"><span>.534</span></td>
# <td class="tr-data"><span>.886</span></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="mobile">
# <table>
# <thead>
# <tr class="tr-component-row">
# <th class="th-component-header"></th>
# <th class="th-component-header">AVG</th>
# <th class="th-component-header">HR</th>
# <th class="th-component-header">RBI</th>
# <th class="th-component-header">SB</th>
# <th class="th-component-header">OPS</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><span>2018</span></td>
# <td><span>.330</span></td>
# <td><span>43</span></td>
# <td><span>130</span></td>
# <td><span>6</span></td>
# <td><span>1.031</span></td>
# </tr>
# <tr>
# <td><span>8 Seasons</span></td>
# <td><span>.292</span></td>
# <td><span>195</span></td>
# <td><span>606</span></td>
# <td><span>22</span></td>
# <td><span>.886</span></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <br/>
# <div id="stats-nav">
# <div class="tab-set tabs-4" id="section_nav">
# <a class="active stat-nav" href="/savant-player/j-d-martinez-502110#standard" id="tab_career" value="career">
#                 Career
#               </a>
# <a class="stat-nav" href="/savant-player/j-d-martinez-502110#splits" id="tab_splits" value="splits">
#                 Splits
#               </a>
# <a class="stat-nav" href="/savant-player/j-d-martinez-502110#gamelogs" id="tab_gamelogs" value="gamelogs">
#                     Game Logs
#                   </a>
# <a class="stat-nav" href="/savant-player/j-d-martinez-502110#statcast" id="tab_statcast" value="statcast">
#                 Statcast
#               </a>
# </div>
# <div class="filters" id="filters_nav_career">
# <div class="stat-type" id="level_nav">
# <ul class="horizontal-list">
# <li>
# <button class="active" id="level_mlb_career" value="MLB"><span>MLB</span></button>
# </li>
# <li>
# <button id="level_minors_career" value="MINORS"><span>Minors</span></button>
# </li>
# </ul>
# </div>
# <div class="stat-type" id="stat_type_nav">
# <ul class="horizontal-list">
# <li>
# <button class="stat-view active" id="stats_nav_type_batting"><span>Batting</span></button>
# </li>
# <li>
# <button class="stat-view" id="stats_nav_type_fielding"><span>Fielding</span></button>
# </li>
# </ul>
# </div>
# <div>
# <ul class="horizontal-list" style="display: block;">
# <li>
# <div class="dropdown">
# <select class="control-career-mlb" id="game-type-standard-mlb">
# <option value="A">All-Star</option>
# <option selected="" value="R">Regular season</option>
# <option value="F">Wild Card</option>
# <option value="D">Division Series</option>
# <option value="L">League Championship Series</option>
# <option value="W">World Series</option>
# <option value="S">Spring Training</option>
# <option value="P">MLB Postseason Cumulative</option>
# </select>
# <select class="control-career-milb" id="game-type-standard-milb" style="display: none;">
# <option value="A">All-Star</option>
# <option selected="" value="R">Regular season</option>
# <option value="P">Minors Postseason Cumulative</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul></div>
# </div>
# <div class="filters" id="filters_nav_splits" style="display: none;">
# <div class="stat-type" id="level_nav">
# <ul class="horizontal-list">
# <li>
# <button class="active" id="level_mlb_splits" value="MLB"><span>MLB</span></button>
# </li>
# <li>
# <button id="level_minors_splits" value="MINORS"><span>Minors</span></button>
# </li>
# </ul>
# </div>
# <div>
# <ul class="horizontal-list control-splits-mlb">
# <li>
# <div class="dropdown">
# <select class="splits-mlb" id="splits-type-mlb">
# <option value="R">Regular season</option>
# <option value="S">Spring Training</option>
# <option value="P">Postseason Cumulative</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# <ul class="horizontal-list control-splits-mlb">
# <li>
# <div class="dropdown">
# <select class="splits-mlb" id="splits-season-mlb">
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# <ul class="horizontal-list control-splits-milb" style="display:none;">
# <li>
# <div class="dropdown">
# <select class="splits-milb" id="splits-type-milb">
# <option value="R">Regular season</option>
# <option value="S">Spring Training</option>
# <option value="P">Postseason Cumulative</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# <ul class="horizontal-list control-splits-milb" style="display:none;">
# <li>
# <div class="dropdown">
# <select class="splits-milb" id="splits-season-milb">
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="filters" id="filters_nav_gamelogs" style="display: none;">
# <div class="stat-type" id="level_nav">
# <ul class="horizontal-list">
# <li>
# <button class="active" id="level_mlb_gamelogs" value="MLB"><span>MLB</span></button>
# </li>
# <li>
# <button id="level_minors_gamelogs" value="MINORS"><span>Minors</span></button>
# </li>
# </ul>
# </div>
# <div>
# <ul class="horizontal-list control-gamelogs-mlb">
# <li>
# <div class="dropdown">
# <select class="gamelogs-mlb" id="gamelogs-type-mlb">
# <option value="R">Regular season</option>
# <option value="S">Spring Training</option>
# <option value="P">Postseason Cumulative</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# <ul class="horizontal-list control-gamelogs-mlb">
# <li>
# <div class="dropdown">
# <select class="gamelogs-mlb" id="gamelogs-season-mlb">
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# <ul class="horizontal-list control-gamelogs-milb" style="display:none;">
# <li>
# <div class="dropdown">
# <select class="gamelogs-milb" id="gamelogs-type-milb">
# <option value="R">Regular season</option>
# <option value="S">Spring Training</option>
# <option value="P">Postseason Cumulative</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# <ul class="horizontal-list control-gamelogs-milb" style="display:none;">
# <li>
# <div class="dropdown">
# <select class="gamelogs-milb" id="gamelogs-season-milb">
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="filters" id="filters_nav_statcast" style="display: none;">
# <div class="stat-type" id="statcast_type_nav">
# <ul class="horizontal-list">
# <li>
# <button class="statcast-view active" id="statcast_nav_type_batting"><span>Batting</span></button>
# </li>
# <li>
# <button class="statcast-view" id="statcast_nav_type_fielding"><span>Fielding</span></button>
# </li>
# <li>
# <button class="statcast-view" id="statcast_nav_type_running"><span>Running</span></button>
# </li>
# <li>
# <button class="statcast-view" id="statcast_nav_type_histograms"><span>Histograms</span></button>
# </li>
# <li>
# <button class="statcast-view" id="statcast_nav_type_zones"><span>Zones</span></button>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="tab" id="div_career">
# <div id="mlb_career">
# <div class="stat-group" id="mlbHitting">
# <h3>Standard MLB Batting Statistics</h3>
# <div class="table-savant standard-mlb" id="hittingStandard">
# <table><thead><tr class="tr-component-row"><th class="th-component-header " id="hittingStandard_th-0"></th><th class="th-component-header align-left " id="hittingStandard_th-1">Season</th><th class="th-component-header align-left " id="hittingStandard_th-2">Tm</th><th class="th-component-header " id="hittingStandard_th-3">LG</th><th class="th-component-header " id="hittingStandard_th-4">G</th><th class="th-component-header " id="hittingStandard_th-5">PA</th><th class="th-component-header " id="hittingStandard_th-6">AB</th><th class="th-component-header " id="hittingStandard_th-7">R</th><th class="th-component-header " id="hittingStandard_th-8">H</th><th class="th-component-header " id="hittingStandard_th-9">2B</th><th class="th-component-header " id="hittingStandard_th-10">3B</th><th class="th-component-header " id="hittingStandard_th-11">HR</th><th class="th-component-header " id="hittingStandard_th-12">RBI</th><th class="th-component-header " id="hittingStandard_th-13">BB</th><th class="th-component-header " id="hittingStandard_th-14">SO</th><th class="th-component-header " id="hittingStandard_th-15">SB</th><th class="th-component-header " id="hittingStandard_th-16">CS</th><th class="th-component-header " id="hittingStandard_th-17">HBP</th><th class="th-component-header " id="hittingStandard_th-18">AVG</th><th class="th-component-header " id="hittingStandard_th-19">OBP</th><th class="th-component-header " id="hittingStandard_th-20">SLG</th><th class="th-component-header " id="hittingStandard_th-21">OPS</th></tr></thead><tbody><tr class="default-table-row " id="hittingStandard-tr_0"><td class="tr-data all-star align-center " title="All Star Season"> <span></span></td><td class="tr-data align-left "> <span>2011</span></td><td class="tr-data align-left "><svg class="table-team-logo"><use xlink:href="#team-cap-on-light-117" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg> <span>HOU</span></td><td class="tr-data "> <span>NL</span></td><td class="tr-data "> <span>53</span></td><td class="tr-data "> <span>226</span></td><td class="tr-data "> <span>208</span></td><td class="tr-data "> <span>29</span></td><td class="tr-data "> <span class=" hits underline" id="hits underline_502110_2011">57</span></td><td class="tr-data "> <span class=" doubles underline" id="doubles underline_502110_2011">13</span></td><td class="tr-data "> <span class=" triples underline" id="triples underline_502110_2011">0</span></td><td class="tr-data "> <span class=" homeruns underline" id="homeruns underline_502110_2011">6</span></td><td class="tr-data "> <span>35</span></td><td class="tr-data "> <span class=" walks underline" id="walks underline_502110_2011">13</span></td><td class="tr-data "> <span class=" strikeouts underline" id="strikeouts underline_502110_2011">48</span></td><td class="tr-data "> <span>0</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>2</span></td><td class="tr-data "> <span>.274</span></td><td class="tr-data "> <span>.319</span></td><td class="tr-data "> <span>.423</span></td><td class="tr-data "> <span>.742</span></td></tr><tr class="default-table-row " id="hittingStandard-tr_1"><td class="tr-data all-star align-center " title="All Star Season"> <span></span></td><td class="tr-data align-left "> <span>2012</span></td><td class="tr-data align-left "><svg class="table-team-logo"><use xlink:href="#team-cap-on-light-117" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg> <span>HOU</span></td><td class="tr-data "> <span>NL</span></td><td class="tr-data "> <span>113</span></td><td class="tr-data "> <span>439</span></td><td class="tr-data "> <span>395</span></td><td class="tr-data "> <span>34</span></td><td class="tr-data "> <span class=" hits underline" id="hits underline_502110_2012">95</span></td><td class="tr-data "> <span class=" doubles underline" id="doubles underline_502110_2012">14</span></td><td class="tr-data "> <span class=" triples underline" id="triples underline_502110_2012">3</span>< ...
# <div id="legend">
# <span class="all-star">*</span>: All Star Season,
#                             Rankings AL/NL: <span class="ranking-5">Top 5</span>
# <span class="ranking-10">10</span>
# <span class="ranking-15">15</span>
# <span class="ranking-20">20</span>,
#                             <span class="underline">     </span> Click for Chart.
#                         </div> <br/>
# <h3>Advanced MLB Batting Statistics</h3>
# <table><thead><tr class="tr-component-row"><th class="th-component-header align-left " id="hittingStandard_th-0">Season</th><th class="th-component-header align-left " id="hittingStandard_th-1">Tm</th><th class="th-component-header " id="hittingStandard_th-2">LG</th><th class="th-component-header " id="hittingStandard_th-3">PA</th><th class="th-component-header " id="hittingStandard_th-4">TB</th><th class="th-component-header " id="hittingStandard_th-5">LOB</th><th class="th-component-header " id="hittingStandard_th-6">SAC</th><th class="th-component-header " id="hittingStandard_th-7">SF</th><th class="th-component-header " id="hittingStandard_th-8">BABIP</th><th class="th-component-header " id="hittingStandard_th-9">XBH</th><th class="th-component-header " id="hittingStandard_th-10">GIDP</th><th class="th-component-header " id="hittingStandard_th-11">GIDPO</th><th class="th-component-header " id="hittingStandard_th-12">NP</th><th class="th-component-header " id="hittingStandard_th-13">P/PA</th><th class="th-component-header " id="hittingStandard_th-14">K/PA</th><th class="th-component-header " id="hittingStandard_th-15">HR/PA</th><th class="th-component-header " id="hittingStandard_th-16">BB/K</th><th class="th-component-header " id="hittingStandard_th-17">ISO</th><th class="th-component-header " id="hittingStandard_th-18">ROE</th><th class="th-component-header " id="hittingStandard_th-19">WO</th></tr></thead><tbody><tr class="default-table-row " id="hittingStandard-tr_0"><td class="tr-data align-left "> <span>2011</span></td><td class="tr-data align-left "><svg class="table-team-logo"><use xlink:href="#team-cap-on-light-117" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg> <span>HOU</span></td><td class="tr-data "> <span>NL</span></td><td class="tr-data "> <span>226</span></td><td class="tr-data "> <span>88</span></td><td class="tr-data "> <span>80</span></td><td class="tr-data "> <span>0</span></td><td class="tr-data "> <span>3</span></td><td class="tr-data "> <span>.325</span></td><td class="tr-data "> <span>19</span></td><td class="tr-data "> <span>4</span></td><td class="tr-data "> <span>28</span></td><td class="tr-data "> <span>853</span></td><td class="tr-data "> <span>3.77</span></td><td class="tr-data "> <span>.212</span></td><td class="tr-data "> <span>.027</span></td><td class="tr-data "> <span>.271</span></td><td class="tr-data "> <span>.149</span></td><td class="tr-data "> <span>.149</span></td><td class="tr-data "> <span>0</span></td></tr><tr class="default-table-row " id="hittingStandard-tr_1"><td class="tr-data align-left "> <span>2012</span></td><td class="tr-data align-left "><svg class="table-team-logo"><use xlink:href="#team-cap-on-light-117" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg> <span>HOU</span></td><td class="tr-data "> <span>NL</span></td><td class="tr-data "> <span>439</span></td><td class="tr-data "> <span>148</span></td><td class="tr-data "> <span>187</span></td><td class="tr-data "> <span>0</span></td><td class="tr-data "> <span>2</span></td><td class="tr-data "> <span>.290</span></td><td class="tr-data "> <span>28</span></td><td class="tr-data "> <span>18</span></td><td class="tr-data "> <span>62</span></td><td class="tr-data "> <span>1643</span></td><td class="tr-data "> <span>3.74</span></td><td class="tr-data "> <span>.219</span></td><td class="tr-data "> <span>.025</span></td><td class="tr-data "> <span>.417</span></td><td class="tr-data "> <span>.134</span></td><td class="tr-data "> <span>.134</span></td><td class="tr-data "> <span>0</span></td></tr><tr class="default-table-row " id="hittingStandard-tr_2"><td class="tr-data align-left "> <span>2013</span></td><td class="tr-data align-left "><svg class="table-team-logo"><use xlink:href="#team-cap-on-light-117" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg> <span>HOU</span></td><td class="tr-data "> <span>AL</span></td><td class="tr-data "> <span>310</span></td><td class="tr-data "> <span>112</span></td><td clas ...
# </div>
# <div class="table-savant standard-load-mlb" id="loadStandardHitting"></div>
# </div>
# <div class="stat-group" id="mlbPitching" style="display: none;">
# <h3>Standard MLB Pitching Statistics</h3>
#                             No MLB Pitching Statistics.
#                     </div>
# <div class="stat-group" id="mlbFielding" style="display:none;">
# <h3>Standard MLB Fielding Statistics</h3>
# <div class="table-savant standard-mlb" id="fieldingStandard">
# <table><thead><tr class="tr-component-row"><th class="th-component-header align-left " id="fieldingStandard_th-0">Season</th><th class="th-component-header align-left " id="fieldingStandard_th-1">Tm</th><th class="th-component-header align-left " id="fieldingStandard_th-2">LG</th><th class="th-component-header align-left " id="fieldingStandard_th-3">POS</th><th class="th-component-header " id="fieldingStandard_th-4">G</th><th class="th-component-header " id="fieldingStandard_th-5">GS</th><th class="th-component-header " id="fieldingStandard_th-6">INN</th><th class="th-component-header " id="fieldingStandard_th-7">TC</th><th class="th-component-header " id="fieldingStandard_th-8">PO</th><th class="th-component-header " id="fieldingStandard_th-9">A</th><th class="th-component-header " id="fieldingStandard_th-10">E</th><th class="th-component-header " id="fieldingStandard_th-11">DP</th><th class="th-component-header " id="fieldingStandard_th-12">RF</th><th class="th-component-header " id="fieldingStandard_th-13">FPCT%</th></tr></thead><tbody><tr class="default-table-row " id="fieldingStandard-tr_0"><td class="tr-data align-left "> <span>2011</span></td><td class="tr-data align-left "><svg class="table-team-logo"><use xlink:href="#team-cap-on-light-117" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg> <span>HOU</span></td><td class="tr-data align-left "> <span>NL</span></td><td class="tr-data align-left "> <span>LF</span></td><td class="tr-data "> <span>51</span></td><td class="tr-data "> <span>51</span></td><td class="tr-data "> <span>436.1</span></td><td class="tr-data "> <span>98</span></td><td class="tr-data "> <span>92</span></td><td class="tr-data "> <span>5</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>2</span></td><td class="tr-data "> <span></span></td><td class="tr-data "> <span>.990</span></td></tr><tr class="default-table-row " id="fieldingStandard-tr_1"><td class="tr-data align-left "> <span>2011</span></td><td class="tr-data align-left "><svg class="table-team-logo"><use xlink:href="#team-cap-on-light-117" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg> <span>HOU</span></td><td class="tr-data align-left "> <span>NL</span></td><td class="tr-data align-left "> <span>RF</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>9.0</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>0</span></td><td class="tr-data "> <span>0</span></td><td class="tr-data "> <span>0</span></td><td class="tr-data "> <span></span></td><td class="tr-data "> <span>1.000</span></td></tr><tr class="default-table-row " id="fieldingStandard-tr_2"><td class="tr-data align-left "> <span>2011</span></td><td class="tr-data align-left "><svg class="table-team-logo"><use xlink:href="#team-cap-on-light-117" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg> <span>HOU</span></td><td class="tr-data align-left "> <span>NL</span></td><td class="tr-data align-left "> <span>OF</span></td><td class="tr-data "> <span>52</span></td><td class="tr-data "> <span>52</span></td><td class="tr-data "> <span>445.1</span></td><td class="tr-data "> <span>99</span></td><td class="tr-data "> <span>93</span></td><td class="tr-data "> <span>5</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>2</span></td><td class="tr-data "> <span></span></td><td class="tr-data "> <span>.990</span></td></tr><tr class="default-table-row " id="fieldingStandard-tr_3"><td class="tr-data align-left "> <span>2012</span></td><td class="tr-data align-left "><svg class="table-team-logo"><use xlink:href="#team-cap-on-light-117" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg> <span>HOU</span></td><td class="tr-data align-left "> <span>NL</span></td><td class="tr-data align-left "> <span>LF</span></td><td class="tr-data "> <span>100</span></td><td class="tr-data "> <span>97</span></t ...
# </div>
# <div class="table-savant standard-load-mlb" id="loadStandardFielding"></div>
# </div>
# </div>
# <div id="milb_career" style="display: none;">
# <div class="stat-group" id="milbHitting">
# <h3>Standard Minor League Batting Statistics</h3>
# <div class="table-savant standard-milb" id="hittingStandardMiLB">
# <table><thead><tr class="tr-component-row"><th class="th-component-header align-left " id="hittingStandardMiLB_th-0">Season</th><th class="th-component-header align-left " id="hittingStandardMiLB_th-1">Tm</th><th class="th-component-header align-left " id="hittingStandardMiLB_th-2">LG</th><th class="th-component-header align-left " id="hittingStandardMiLB_th-3">L</th><th class="th-component-header " id="hittingStandardMiLB_th-4">G</th><th class="th-component-header " id="hittingStandardMiLB_th-5">PA</th><th class="th-component-header " id="hittingStandardMiLB_th-6">AB</th><th class="th-component-header " id="hittingStandardMiLB_th-7">R</th><th class="th-component-header " id="hittingStandardMiLB_th-8">H</th><th class="th-component-header " id="hittingStandardMiLB_th-9">2B</th><th class="th-component-header " id="hittingStandardMiLB_th-10">3B</th><th class="th-component-header " id="hittingStandardMiLB_th-11">HR</th><th class="th-component-header " id="hittingStandardMiLB_th-12">RBI</th><th class="th-component-header " id="hittingStandardMiLB_th-13">BB</th><th class="th-component-header " id="hittingStandardMiLB_th-14">SO</th><th class="th-component-header " id="hittingStandardMiLB_th-15">SB</th><th class="th-component-header " id="hittingStandardMiLB_th-16">CS</th><th class="th-component-header " id="hittingStandardMiLB_th-17">HBP</th><th class="th-component-header " id="hittingStandardMiLB_th-18">AVG</th><th class="th-component-header " id="hittingStandardMiLB_th-19">OBP</th><th class="th-component-header " id="hittingStandardMiLB_th-20">SLG</th><th class="th-component-header " id="hittingStandardMiLB_th-21">OPS</th></tr></thead><tbody><tr class="default-table-row " id="hittingStandardMiLB-tr_0"><td class="tr-data align-left "> <span>2009</span></td><td class="tr-data align-left "> <span>2 Teams</span></td><td class="tr-data align-left "> <span></span></td><td class="tr-data align-left "> <span>Minors</span></td><td class="tr-data "> <span>72</span></td><td class="tr-data "> <span>291</span></td><td class="tr-data "> <span>264</span></td><td class="tr-data "> <span>42</span></td><td class="tr-data "> <span>92</span></td><td class="tr-data "> <span>24</span></td><td class="tr-data "> <span>3</span></td><td class="tr-data "> <span>12</span></td><td class="tr-data "> <span>56</span></td><td class="tr-data "> <span>20</span></td><td class="tr-data "> <span>44</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>0</span></td><td class="tr-data "> <span>4</span></td><td class="tr-data "> <span>.348</span></td><td class="tr-data "> <span>.399</span></td><td class="tr-data "> <span>.598</span></td><td class="tr-data "> <span>.997</span></td></tr><tr class="default-table-row " id="hittingStandardMiLB-tr_1"><td class="tr-data align-left "> <span>2009</span></td><td class="tr-data align-left "> <span>Greeneville Astros</span></td><td class="tr-data align-left "> <span>APP</span></td><td class="tr-data align-left "> <span>ROK</span></td><td class="tr-data "> <span>19</span></td><td class="tr-data "> <span>83</span></td><td class="tr-data "> <span>77</span></td><td class="tr-data "> <span>17</span></td><td class="tr-data "> <span>31</span></td><td class="tr-data "> <span>9</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>5</span></td><td class="tr-data "> <span>23</span></td><td class="tr-data "> <span>5</span></td><td class="tr-data "> <span>14</span></td><td class="tr-data "> <span>0</span></td><td class="tr-data "> <span>0</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>.403</span></td><td class="tr-data "> <span>.446</span></td><td class="tr-data "> <span>.740</span></td><td class="tr-data "> <span>1.186</span></td></tr><tr class="default-table-row " id="hittingStandardMiLB-tr_2"><td class="tr-data align-left "> <span>2009</span></td><td class="tr-data align-left "> <span>Tri-City ValleyCats</span></td><td class="tr-data align-left "> <span>NYP</ ...
# </div>
# <div class="table-savant standard-load-milb" id="loadStandardMiLBHitting"></div>
# </div>
# <div class="stat-group" id="milbPitching" style="display: none;">
# <h3>Standard Minor League Pitching Statistics</h3>
#                                     No Minor League Pitching Statistics.
#                             </div>
# <div class="stat-group" id="milbFielding" style="display:none;">
# <h3>Standard Minor League Fielding Statistics</h3>
# <div class="table-savant standard-milb" id="fieldingStandardMiLB">
# <table><thead><tr class="tr-component-row"><th class="th-component-header align-left " id="fieldingStandardMiLB_th-0">Season</th><th class="th-component-header align-left " id="fieldingStandardMiLB_th-1">Tm</th><th class="th-component-header " id="fieldingStandardMiLB_th-2">LG</th><th class="th-component-header align-left " id="fieldingStandardMiLB_th-3">L</th><th class="th-component-header align-left " id="fieldingStandardMiLB_th-4">POS</th><th class="th-component-header " id="fieldingStandardMiLB_th-5">G</th><th class="th-component-header " id="fieldingStandardMiLB_th-6">GS</th><th class="th-component-header " id="fieldingStandardMiLB_th-7">INN</th><th class="th-component-header " id="fieldingStandardMiLB_th-8">TC</th><th class="th-component-header " id="fieldingStandardMiLB_th-9">PO</th><th class="th-component-header " id="fieldingStandardMiLB_th-10">A</th><th class="th-component-header " id="fieldingStandardMiLB_th-11">E</th><th class="th-component-header " id="fieldingStandardMiLB_th-12">DP</th><th class="th-component-header " id="fieldingStandardMiLB_th-13">RF</th><th class="th-component-header " id="fieldingStandardMiLB_th-14">FPCT%</th></tr></thead><tbody><tr class="default-table-row " id="fieldingStandardMiLB-tr_0"><td class="tr-data align-left "> <span>2009</span></td><td class="tr-data align-left "> <span>2 Teams</span></td><td class="tr-data "> <span></span></td><td class="tr-data align-left "> <span>Minors</span></td><td class="tr-data align-left "> <span>1B</span></td><td class="tr-data "> <span>2</span></td><td class="tr-data "> <span>2</span></td><td class="tr-data "> <span>18.0</span></td><td class="tr-data "> <span>22</span></td><td class="tr-data "> <span>19</span></td><td class="tr-data "> <span>2</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span></span></td><td class="tr-data "> <span>.955</span></td></tr><tr class="default-table-row " id="fieldingStandardMiLB-tr_1"><td class="tr-data align-left "> <span>2009</span></td><td class="tr-data align-left "> <span>2 Teams</span></td><td class="tr-data "> <span></span></td><td class="tr-data align-left "> <span>Minors</span></td><td class="tr-data align-left "> <span>LF</span></td><td class="tr-data "> <span>30</span></td><td class="tr-data "> <span>29</span></td><td class="tr-data "> <span>242.0</span></td><td class="tr-data "> <span>61</span></td><td class="tr-data "> <span>55</span></td><td class="tr-data "> <span>4</span></td><td class="tr-data "> <span>2</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span></span></td><td class="tr-data "> <span>.967</span></td></tr><tr class="default-table-row " id="fieldingStandardMiLB-tr_2"><td class="tr-data align-left "> <span>2009</span></td><td class="tr-data align-left "> <span>2 Teams</span></td><td class="tr-data "> <span></span></td><td class="tr-data align-left "> <span>Minors</span></td><td class="tr-data align-left "> <span>OF</span></td><td class="tr-data "> <span>30</span></td><td class="tr-data "> <span>29</span></td><td class="tr-data "> <span>242.0</span></td><td class="tr-data "> <span>61</span></td><td class="tr-data "> <span>55</span></td><td class="tr-data "> <span>4</span></td><td class="tr-data "> <span>2</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span></span></td><td class="tr-data "> <span>.967</span></td></tr><tr class="default-table-row " id="fieldingStandardMiLB-tr_3"><td class="tr-data align-left "> <span>2009</span></td><td class="tr-data align-left "> <span>Tri-City ValleyCats</span></td><td class="tr-data "> <span>NYP</span></td><td class="tr-data align-left "> <span>A(Short)</span></td><td class="tr-data align-left "> <span>1B</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>1</span></td><td class="tr-data "> <span>9.0</span></td><td class="tr-data "> <span>10</span></td><td class="tr-data "> <span>9</span></td><td class="tr-data "> ...
# </div>
# <div class="table-savant standard-load-milb" id="loadStandardMiLBFielding"></div>
# </div>
# </div>
# <section id="statcast-section">
# <br/>
# <h2><span>Statcast - Batting</span></h2>
# <div class="divider"></div>
# <div class="table-savant" id="statcast_batter">
# <table>
# <thead>
# <tr class="tr-component-row">
# <th class="th-component-header align-left header" id="statcast_th-0">Season</th>
# <th class="th-component-header align-right header" id="statcast_th-1">Pitches</th>
# <th class="th-component-header align-right header" id="statcast_th-2">Batted Balls</th>
# <th class="th-component-header align-right header" id="statcast_th-3">Barrels</th>
# <th class="th-component-header align-right header" id="statcast_th-4">Barrel %</th>
# <th class="th-component-header align-right header" id="statcast_th-5">Exit Velocity</th>
# <th class="th-component-header align-right header" id="statcast_th-6">Launch Angle</th>
# <th class="th-component-header align-right header" id="statcast_th-7">XBA</th>
# <th class="th-component-header align-right header" id="statcast_th-8">XSLG</th>
# <th class="th-component-header align-right header" id="statcast_th-9">WOBA</th>
# <th class="th-component-header align-right header" id="statcast_th-10">XWOBA</th>
# <th class="th-component-header align-right header" id="statcast_th-11">XWOBACON</th>
# <th class="th-component-header align-right header" id="statcast_th-12">Hard Hit %</th>
# </tr>
# </thead>
# <tbody>
# <tr class="default-table-row " style="background-color:  #ffffff;">
# <td class="tr-data align-left "> <span>2015</span></td>
# <td class="tr-data align-right "> <span>2606</span></td>
# <td class="tr-data align-right "> <span>421</span></td>
# <td class="tr-data align-right "> <span>74</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 127, 127)" title="Top 1% of League">17.6</span></td>
# <td class="tr-data align-right "> <span class=" exitVelocity underline" id="exitVelocity underline_502110_2015">91.2</span></td>
# <td class="tr-data align-right "> <span class=" launchAngle underline" id="launchAngle underline_502110_2015">16.0</span></td>
# <td class="tr-data align-right "> <span>.279</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 142, 142)" title="Top 2% of League">.591</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 236, 236)" title="Top 9% of League">.372</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 205, 205)" title="Top 6% of League">.389</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 127, 127)" title="Top 6% of League">.517</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 142, 142)" title="Top 2% of League">48.7</span></td>
# </tr>
# <tr class="default-table-row " style="background-color:  #ffffff;">
# <td class="tr-data align-left "> <span>2016</span></td>
# <td class="tr-data align-right "> <span>2022</span></td>
# <td class="tr-data align-right "> <span>337</span></td>
# <td class="tr-data align-right "> <span>48</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 185, 185)" title="Top 5% of League">14.2</span></td>
# <td class="tr-data align-right "> <span class=" exitVelocity underline" id="exitVelocity underline_502110_2016" style="background-color: rgb(255, 234, 234)" title="Top 8% of League">91.5</span></td>
# <td class="tr-data align-right "> <span class=" launchAngle underline" id="launchAngle underline_502110_2016">13.4</span></td>
# <td class="tr-data align-right "> <span>.291</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 152, 152)" title="Top 2% of League">.568</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 226, 226)" title="Top 8% of League">.384</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 193, 193)" title="Top 5% of League">.396</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 135, 135)" title="Top 5% of League">.503</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 193, 193)" title="Top 5% of League">46.9</span></td>
# </tr>
# <tr class="default-table-row " style="background-color:  #ffffff;">
# <td class="tr-data align-left "> <span>2017</span></td>
# <td class="tr-data align-right "> <span>1911</span></td>
# <td class="tr-data align-right "> <span>308</span></td>
# <td class="tr-data align-right "> <span>60</span></td>
# <td class="tr-data align-right "> <span>19.5</span></td>
# <td class="tr-data align-right "> <span class=" exitVelocity underline" id="exitVelocity underline_502110_2017">91.0</span></td>
# <td class="tr-data align-right "> <span class=" launchAngle underline" id="launchAngle underline_502110_2017">15.2</span></td>
# <td class="tr-data align-right "> <span>.294</span></td>
# <td class="tr-data align-right "> <span>.682</span></td>
# <td class="tr-data align-right "> <span>.430</span></td>
# <td class="tr-data align-right "> <span>.430</span></td>
# <td class="tr-data align-right "> <span>.571</span></td>
# <td class="tr-data align-right "> <span>48.7</span></td>
# </tr>
# <tr class="default-table-row " style="background-color:  #ffffff;">
# <td class="tr-data align-left "> <span>2018</span></td>
# <td class="tr-data align-right "> <span>2519</span></td>
# <td class="tr-data align-right "> <span>430</span></td>
# <td class="tr-data align-right "> <span>69</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 136, 136)" title="Top 1% of League">16.0</span></td>
# <td class="tr-data align-right "> <span class=" exitVelocity underline" id="exitVelocity underline_502110_2018" style="background-color: rgb(255, 154, 154)" title="Top 3% of League">93.0</span></td>
# <td class="tr-data align-right "> <span class=" launchAngle underline" id="launchAngle underline_502110_2018">10.6</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 128, 128)" title="Top 1% of League">.309</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 119, 119)" title="Top 1% of League">.619</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 136, 136)" title="Top 1% of League">.428</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 136, 136)" title="Top 1% of League">.417</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 119, 119)" title="Top 1% of League">.518</span></td>
# <td class="tr-data align-right "> <span class="rank" style="background-color: rgb(255, 119, 119)" title="Top 1% of League">52.1</span></td>
# </tr>
# <tr class="default-table-row static" style="background-color:  #c2c2c2;">
# <td class="tr-data align-left "> <span>ALL</span></td>
# <td class="tr-data align-right "> <span>9058</span></td>
# <td class="tr-data align-right "> <span>1496</span></td>
# <td class="tr-data align-right "> <span>251</span></td>
# <td class="tr-data align-right "> <span>16.8</span></td>
# <td class="tr-data align-right "> <span>91.7</span></td>
# <td class="tr-data align-right "> <span>13.7</span></td>
# <td class="tr-data align-right "> <span>.293</span></td>
# <td class="tr-data align-right "> <span>.613</span></td>
# <td class="tr-data align-right "> <span>.403</span></td>
# <td class="tr-data align-right "> <span>.407</span></td>
# <td class="tr-data align-right "> <span>.525</span></td>
# <td class="tr-data align-right "> <span>49.3</span></td>
# </tr>
# <tr class="default-table-row static" style="background-color:  #f5f5f5;">
# <td class="tr-data align-left "> <span>MLB</span></td>
# <td class="tr-data align-right "> <span></span></td>
# <td class="tr-data align-right "> <span></span></td>
# <td class="tr-data align-right "> <span>31256</span></td>
# <td class="tr-data align-right "> <span>6.1</span></td>
# <td class="tr-data align-right "> <span>87.3</span></td>
# <td class="tr-data align-right "> <span>10.9</span></td>
# <td class="tr-data align-right "> <span>.246</span></td>
# <td class="tr-data align-right "> <span>.403</span></td>
# <td class="tr-data align-right "> <span>.317</span></td>
# <td class="tr-data align-right "> <span>.314</span></td>
# <td class="tr-data align-right "> <span>.363</span></td>
# <td class="tr-data align-right "> <span>34.1</span></td>
# </tr>
# </tbody>
# </table> </div>
# </section>
# <section id="leaderboards">
# <br/>
# <h2><span>Rankings</span></h2>
# <div class="divider"></div>
# <div class="leaderboards-container collapsed">
# <div class="leaderboard-item">
# <h4>Home Runs</h4>
# <table>
# <thead>
# <tr>
# <th class="time-col">Year</th>
# <th class="stat-col number-data">HR</th>
# <th class="rank-col">Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="time-col">
# <td>2018</td>
# <td class="stat-col">43</td>
# <td class="rank-col">2nd in AL</td>
# </tr>
# <tr class="time-col">
# <td>2015</td>
# <td class="stat-col">38</td>
# <td class="rank-col">8th in AL</td>
# </tr>
# <tr class="time-col">
# <td>2014</td>
# <td class="stat-col">23</td>
# <td class="rank-col">17th in AL</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="leaderboard-item">
# <h4>Strikeouts</h4>
# <table>
# <thead>
# <tr>
# <th class="time-col">Year</th>
# <th class="stat-col number-data">SO</th>
# <th class="rank-col">Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="time-col">
# <td>2018</td>
# <td class="stat-col">146</td>
# <td class="rank-col">20th in AL</td>
# </tr>
# <tr class="time-col">
# <td>2015</td>
# <td class="stat-col">178</td>
# <td class="rank-col">2nd in AL</td>
# </tr>
# <tr class="time-col">
# <td>2014</td>
# <td class="stat-col">126</td>
# <td class="rank-col">25th in AL</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="leaderboard-item">
# <h4>Runs Batted In</h4>
# <table>
# <thead>
# <tr>
# <th class="time-col">Year</th>
# <th class="stat-col number-data">RBI</th>
# <th class="rank-col">Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="time-col">
# <td>2018</td>
# <td class="stat-col">130</td>
# <td class="rank-col">1st in AL</td>
# </tr>
# <tr class="time-col">
# <td>2015</td>
# <td class="stat-col">102</td>
# <td class="rank-col">7th in AL</td>
# </tr>
# <tr class="time-col">
# <td>2014</td>
# <td class="stat-col">76</td>
# <td class="rank-col">24th in AL</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="leaderboard-item">
# <h4>Games Played</h4>
# <table>
# <thead>
# <tr>
# <th class="time-col">Year</th>
# <th class="stat-col number-data">BP</th>
# <th class="rank-col">Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="time-col">
# <td>2018</td>
# <td class="stat-col">150</td>
# <td class="rank-col">18th in AL</td>
# </tr>
# <tr class="time-col">
# <td>2015</td>
# <td class="stat-col">158</td>
# <td class="rank-col">9th in AL</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="leaderboard-item">
# <h4>Runs</h4>
# <table>
# <thead>
# <tr>
# <th class="time-col">Year</th>
# <th class="stat-col number-data">R</th>
# <th class="rank-col">Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="time-col">
# <td>2018</td>
# <td class="stat-col">111</td>
# <td class="rank-col">3rd in AL</td>
# </tr>
# <tr class="time-col">
# <td>2015</td>
# <td class="stat-col">93</td>
# <td class="rank-col">14th in AL</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="leaderboard-item">
# <h4>Doubles</h4>
# <table>
# <thead>
# <tr>
# <th class="time-col">Year</th>
# <th class="stat-col number-data">2B</th>
# <th class="rank-col">Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="time-col">
# <td>2018</td>
# <td class="stat-col">37</td>
# <td class="rank-col">14th in AL</td>
# </tr>
# <tr class="time-col">
# <td>2016</td>
# <td class="stat-col">35</td>
# <td class="rank-col">14th in AL</td>
# </tr>
# <tr class="time-col">
# <td>2015</td>
# <td class="stat-col">33</td>
# <td class="rank-col">23rd in AL</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="leaderboard-item">
# <h4>Hits</h4>
# <table>
# <thead>
# <tr>
# <th class="time-col">Year</th>
# <th class="stat-col number-data">H</th>
# <th class="rank-col">Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="time-col">
# <td>2018</td>
# <td class="stat-col">188</td>
# <td class="rank-col">2nd in AL</td>
# </tr>
# <tr class="time-col">
# <td>2015</td>
# <td class="stat-col">168</td>
# <td class="rank-col">17th in AL</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="leaderboard-item">
# <h4>Batting Average</h4>
# <table>
# <thead>
# <tr>
# <th class="time-col">Year</th>
# <th class="stat-col number-data">AVG</th>
# <th class="rank-col">Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="time-col">
# <td>2018</td>
# <td class="stat-col">.330</td>
# <td class="rank-col">2nd in AL</td>
# </tr>
# <tr class="time-col">
# <td>2016</td>
# <td class="stat-col">.307</td>
# <td class="rank-col">8th in AL</td>
# </tr>
# <tr class="time-col">
# <td>2015</td>
# <td class="stat-col">.282</td>
# <td class="rank-col">22nd in AL</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="leaderboard-item">
# <h4>At Bats</h4>
# <table>
# <thead>
# <tr>
# <th class="time-col">Year</th>
# <th class="stat-col number-data">AB</th>
# <th class="rank-col">Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="time-col">
# <td>2018</td>
# ...
# <td class="align-center">-9</td>
# <td class="doaa border-left" id="doaa_2016"></td>
# <td class="align-center" style="border-left: solid 2px #000;">0</td>
# <td class="align-center">-2</td>
# <td class="align-center">-1</td>
# <td class="align-center" style="border-left: solid 2px #000;">-4</td>
# <td class="align-center" style="border-left: solid 2px #000;">0</td>
# <td class="align-center">-1</td>
# <td class="align-center">-4</td>
# <td class="align-center" style="border-left: solid 2px #000; border-right: solid 2px #000;">-5</td>
# <td class="align-center border-left">86</td>
# <td class="align-center">82</td>
# <td class="align-center">-4</td>
# </tr>
# <tr class="default-table-row">
# <td class="align-left">2017</td>
# <td class="align-center">-6</td>
# <td class="doaa border-left" id="doaa_2017"></td>
# <td class="align-center" style="border-left: solid 2px #000;">-2</td>
# <td class="align-center">-1</td>
# <td class="align-center">0</td>
# <td class="align-center" style="border-left: solid 2px #000;">-3</td>
# <td class="align-center" style="border-left: solid 2px #000;">-1</td>
# <td class="align-center">1</td>
# <td class="align-center">-3</td>
# <td class="align-center" style="border-left: solid 2px #000; border-right: solid 2px #000;">-3</td>
# <td class="align-center border-left">86</td>
# <td class="align-center">84</td>
# <td class="align-center">-2</td>
# </tr>
# <tr class="default-table-row">
# <td class="align-left">2018</td>
# <td class="align-center">-7</td>
# <td class="doaa border-left" id="doaa_2018"></td>
# <td class="align-center" style="border-left: solid 2px #000;">-3</td>
# <td class="align-center">1</td>
# <td class="align-center">-3</td>
# <td class="align-center" style="border-left: solid 2px #000;">-5</td>
# <td class="align-center" style="border-left: solid 2px #000;">1</td>
# <td class="align-center">-1</td>
# <td class="align-center">0</td>
# <td class="align-center" style="border-left: solid 2px #000; border-right: solid 2px #000;">0</td>
# <td class="align-center border-left">87</td>
# <td class="align-center">82</td>
# <td class="align-center">-5</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div style="font-size: 12px;">* Due to rounding, a player’s full-season OAA may not align perfectly with the total values of the six directional segments.</div>
# <div>
# <span class="view-toggle" id="statcastShowAll"><a href="/outs_above_average">+ <span id="awardText">View Complete Outs Above Average Leaderboard</span></a></span>
# </div>
# <h2><span>Statcast Fielding Breakdown</span></h2>
# <div class="divider" id="statcast_stats_stats"></div>
# <br/>
# <ul class="horizontal-list control-statcast-mlb" style="margin: 0;">
# <li>
# <div class="dropdown">
# <select class="statcast-mlb" id="statcast-season-mlb">
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# <li>
#
#                                 <div class="dropdown">
# <select class="statcast-mlb" id="statcast-range-perspective">
# <option value="fielder">Fielder Perspective</option>
# <option value="batter">Batter Perspective</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# <div id="statcast-loading" style="display: none;">Loading Chart Data...</div>
# <div class="statcast-chart" id="lineRangeChart" style="overflow-x: auto;"></div>
# <div class="statcast-chart" style="font-size:11px;">* Click Any Legend Option to Reset Chart | <span class="save" id="LineChart">Save Chart</span></div>
# <div class="statcast-chart" id="fieldRangeChart" style="overflow-x: auto;"></div>
# <div class="row statcast-fielding-chart-toggles">
# <div class="col-lg-2">
#                             Hang Time:
#                             <input class="statcast-fielding-range-toggle" id="hangTime" max="8" min="3" step=".05" type="range" value="6.5"/>
# </div>
# <div class="col-lg-2">
#                             Catch Rate GT:
#                             <input class="statcast-fielding-range-toggle" id="catchRateGT" max="1" min="0" step=".05" type="range" value=".05"/>
# </div>
# <div class="col-lg-2">
#                             Catch Rate LT:
#                             <input class="statcast-fielding-range-toggle" id="catchRateLT" max="1" min="0" step=".05" type="range" value="1"/>
# </div>
# <div class="col-lg-2">
#                             Stroke Opacity:
#                             <input class="statcast-fielding-range-toggle" id="statcast-fielding-range-stroke" max="1" min="0" step=".05" type="range" value=".5"/>
# </div>
# <div class="col-lg-2">
#                                 Sprint Speed Range? <input class="statcast-fielding-range-toggle" id="chkSprintSpeed" type="checkbox"/>
# </div>
# </div>
# <div class="statcast-fielding-chart-toggles row" style="padding-top: 20px;">
# <div class="col-lg-2">
#                             Fill Opacity:
#                             <input class="statcast-fielding-range-toggle" id="statcast-fielding-range-fill" max="1" min="0" step=".05" type="range" value="1"/>
# </div>
# <div class="col-lg-2">
#                             Show Hits: <input checked="" class="statcast-fielding-range-toggle" id="chkHits" type="checkbox"/>
# </div>
# <div class="col-lg-2">
#                             Show Outs: <input checked="" class="statcast-fielding-range-toggle" id="chkOuts" type="checkbox"/>
# </div>
# <div class="col-lg-2">
#                             Shows Hulls: <input checked="" class="statcast-fielding-range-toggle" id="chkHull" type="checkbox"/>
# </div>
# <div class="col-lg-2">
# <span class="save" id="fieldRangeChart">Save Chart</span>
# </div>
# </div>
# </div> <div class="statcast-group" id="statcastRunning" style="display:none;">
# <h2><span><a href="#running" name="running">Statcast Running Statistics</a></span></h2>
# <div class="divider" id="statcast_stats_running"></div>
# <div class="table-savant">
# <!-- <table><thead><tr class="tr-component-row"><th id="statcastRunning_th-0"  class="th-component-header align-right ">Season</th><th id="statcastRunning_th-1"  class="th-component-header align-right ">Age</th><th id="statcastRunning_th-2"  class="th-component-header align-right ">Sprint Speed (ft/s)</th><th id="statcastRunning_th-3"  class="th-component-header align-right ">Lg Rank</th><th id="statcastRunning_th-4"  class="th-component-header align-right ">Pos Rank</th><th id="statcastRunning_th-5"  class="th-component-header align-right ">Age Rank</th><th id="statcastRunning_th-6"  class="th-component-header align-right ">% Rank</th></tr></thead><tbody><tr id="statcastRunning-tr_0" class="default-table-row " ><td   class="tr-data align-right " > <span>2015</span></td><td   class="tr-data align-right " > <span>28</span></td><td   class="tr-data align-right " > <span>27.8</span></td><td   class="tr-data align-right " > <span>186</span></td><td   class="tr-data align-right " > <span>22</span></td><td   class="tr-data align-right " > <span>21</span></td><td   class="tr-data align-right " > <span>72.6</span></td></tr><tr id="statcastRunning-tr_1" class="default-table-row " ><td   class="tr-data align-right " > <span>2016</span></td><td   class="tr-data align-right " > <span>29</span></td><td   class="tr-data align-right " > <span>27.0</span></td><td   class="tr-data align-right " > <span>320</span></td><td   class="tr-data align-right " > <span>49</span></td><td   class="tr-data align-right " > <span>31</span></td><td   class="tr-data align-right " > <span>53.8</span></td></tr><tr id="statcastRunning-tr_2" class="default-table-row " ><td   class="tr-data align-right " > <span>2017</span></td><td   class="tr-data align-right " > <span>30</span></td><td   class="tr-data align-right " > <span>26.9</span></td><td   class="tr-data align-right " > <span>335</span></td><td   class="tr-data align-right " > <span>49</span></td><td   class="tr-data align-right " > <span>24</span></td><td   class="tr-data align-right " > <span>50.6</span></td></tr><tr id="statcastRunning-tr_3" class="default-table-row " ><td   class="tr-data align-right " > <span>2018</span></td><td   class="tr-data align-right " > <span>31</span></td><td   class="tr-data align-right " > <span>26.8</span></td><td   class="tr-data align-right " > <span>352</span></td><td   class="tr-data align-right " > <span>5</span></td><td   class="tr-data align-right " > <span>18</span></td><td   class="tr-data align-right " > <span>47.8</span></td></tr></tbody></table> -->
# <div class="table-savant">
# <table>
# <thead>
# <tr class="tr-component-row">
# <th class="th-component-header align-right header" id="statcastRunning_th-0">Season</th>
# <th class="th-component-header align-right header" id="statcastRunning_th-1">Age</th>
# <th class="th-component-header align-right header" id="statcastRunning_th-2">Sprint Speed (ft/s)</th>
# <th class="th-component-header align-right header" id="statcastRunning_th-3">Lg Rank</th>
# <th class="th-component-header align-right header" id="statcastRunning_th-4">Pos Rank</th>
# <th class="th-component-header align-right header" id="statcastRunning_th-5">Age Rank</th>
# <th class="th-component-header align-right header" id="statcastRunning_th-6">% Rank</th>
# </tr>
# </thead>
# <tbody>
# <tr class="default-table-row " id="statcastRunning-tr_0">
# <td class="tr-data align-left "> <span>2015</span></td>
# <td class="tr-data align-right "> <span>28</span></td>
# <td class="tr-data align-right "> <span>27.8</span></td>
# <td class="tr-data align-right "> <span>186</span></td>
# <td class="tr-data align-right "> <span>22</span></td>
# <td class="tr-data align-right "> <span>21</span></td>
# <td class="tr-data align-right "> <span>72.6</span></td>
# </tr>
# <tr class="default-table-row " id="statcastRunning-tr_0">
# <td class="tr-data align-left "> <span>2016</span></td>
# <td class="tr-data align-right "> <span>29</span></td>
# <td class="tr-data align-right "> <span>27.0</span></td>
# <td class="tr-data align-right "> <span>320</span></td>
# <td class="tr-data align-right "> <span>49</span></td>
# <td class="tr-data align-right "> <span>31</span></td>
# <td class="tr-data align-right "> <span>53.8</span></td>
# </tr>
# <tr class="default-table-row " id="statcastRunning-tr_0">
# <td class="tr-data align-left "> <span>2017</span></td>
# <td class="tr-data align-right "> <span>30</span></td>
# <td class="tr-data align-right "> <span>26.9</span></td>
# <td class="tr-data align-right "> <span>335</span></td>
# <td class="tr-data align-right "> <span>49</span></td>
# <td class="tr-data align-right "> <span>24</span></td>
# <td class="tr-data align-right "> <span>50.6</span></td>
# </tr>
# <tr class="default-table-row " id="statcastRunning-tr_0">
# <td class="tr-data align-left "> <span>2018</span></td>
# <td class="tr-data align-right "> <span>31</span></td>
# <td class="tr-data align-right "> <span>26.8</span></td>
# <td class="tr-data align-right "> <span>352</span></td>
# <td class="tr-data align-right "> <span>5</span></td>
# <td class="tr-data align-right "> <span>18</span></td>
# <td class="tr-data align-right "> <span>47.8</span></td>
# </tr>
# </tbody>
# </table>
# </div> </div>
# <div>
# <span class="view-toggle" id="statcastShowAll"><a href="/sprint_speed_leaderboard">+ <span id="awardText">View Complete Sprint Speed Leaderboard</span></a></span>
# </div>
# <br/>
# <!--
#                     <h2><span><a href="#running" name="running">5ft Running Splits</a></span></h2>
#                     <div id="statcast_stats_running" class="divider"></div>
#
#                     <div id="runningSplits"></div>
#                     <ul class="horizontal-list control-splits-mlb" style="margin: 0;">
#                             <li>
#                         <div class="dropdown">
#                                 <select id="runningPos" class="running-chart">
#                                         <option value="">All Positions</option>
#                                         <option value="3">1B</option>
#                                         <option value="4">2B</option>
#                                         <option value="6">SS</option>
#                                         <option value="5">3B</option>
#                                         <option value="7">LF</option>
#                                         <option value="8">CF</option>
#                                         <option value="9">RF</option>
#
#                                 </select>
#                                 <span class="dropdown-arrow">▾</span>
#                         </div>
#                       </li>
#                     </ul>
#                     <div id="runningTable" class="table-savant">
#
#                     </div>
#                 -->
# </div> <div class="statcast-group" id="statcastHistograms" style="display:none;">
# <div id="histogram"></div>
# <ul class="horizontal-list control-splits-mlb">
# <li>
# <div class="dropdown">
# <select class="histogram-chart" id="histogramType">
# <option value="api_h_launch_speed">Exit Velocity</option>
# <option value="api_h_launch_angle">Launch Angle</option>
# <option value="api_h_launch_direction">Launch Direction</option>
# <option value="api_p_release_speed">Pitch Velocity</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# <li>
#
#                             <div class="dropdown">
# <select class="histogram-update" id="histogramEventType">
# <option value="bbe">Batted Balls</option>
# <option value="hr">Home Runs</option>
# <option value="hits">Hits</option>
# <option value="pitch_percent">Percentage</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# <li>
#
#                             <div class="dropdown">
# <select class="histogram-chart" id="histogramGroup">
# <option value="1">1 Point Per Group</option>
# <option selected="" value="5">5 Point Per Group</option>
# <option value="10">10 Point Per Group</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# <li>
#
#                               <div class="dropdown">
# <select class="histogram-chart" id="histogramHandedness">
# <option value="">Handedness</option>
# <option value="R">Right</option>
# <option value="L">Left</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# <li>
#
#                               <div class="dropdown">
# <select class="histogram-chart" id="histogramSeason">
# <option value="">All Seasons</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# <li>
#
#                                   <div class="dropdown">
# <select class="histogram-update" id="histogramColor">
# <option value="all">All One Color</option>
# <option value="hard_hit_percent">Hard Hit %</option>
# <option value="woba">wOBA</option>
# <option value="ba">BA</option>
# <option value="slg">SLG</option>
# <option value="xwoba">xwOBA</option>
# <option value="xba">xBA</option>
# <option value="xslg">xSLG</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# </div> <div class="statcast-group" id="statcastZones" style="display:none;">
# <h2><span>Statcast Zone Charts</span></h2>
# <div class="divider" id="statcast_stats_zones"></div>
# <div style="text-align:center">
# <ul class="horizontal-list control-splits-mlb">
# <li>
# <div class="dropdown">
# <select class="zone-chart" id="ddlZoneSeason">
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# <li>
#
#                           <div class="dropdown">
# <select class="zone-chart" id="ddlZoneHand">
# <option value="">Pitcher Throws</option>
# <option value="R">Right</option>
# <option value="L">Left</option>
# </select>
# <span class="dropdown-arrow">▾</span>
# </div>
# </li>
# </ul>
# </div>
# <div class="zone-charts-container" id="zones"></div>
# </div>
# </section>
# </div>
# <br/>
# </section>
# </div>
# </section>

# %%
hr_df = pd.read_csv('../data/clean_hr.csv')

batter_id = list(hr_df['batter'].unique())

# %%
len(batter_id)
# Out:
# 751

# %%
def get_batters_info(batter_id):
    attrs = {
        'batter_id': [str(x) for x in batter_id],
        'height':[],
        'weight':[],
        'age':[],
        'position':[],
        'bats':[],
        'throws':[]
    }

    attr_names = [
        'height',
        'weight',
        'age',
        'position',
        'bats',
        'throws'
    ]

    for idx, b in enumerate(batter_id):
        url = "https://baseballsavant.mlb.com/savant-player/{}?stats=career-r-hitting-mlb".format(b)
        res =  requests.get(url)
        soup = BeautifulSoup(res.content, 'lxml')
        for col_name, attribute in zip(attr_names, soup.find_all('div', {'class':'box-text'})):
            attrs[col_name].append(str(attribute.text))
        if idx % 50 == 0:
            with open('../data/baseball_player.json', 'w') as f:
                json.dump(attrs, f)
    
    with open('../data/baseball_player.json', 'w') as f:
        json.dump(attrs, f)
    
    return attrs

# %%
batters_info = get_batters_info(batter_id)

# %%
import pandas as pd
import json

# %%
pd.read_json('../data/baseball_player.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-56ca4a6ba4bd> in <module>
# ----> 1 pd.read_json('../data/baseball_player.json')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in read(self)
#     527             )
#     528         else:
# --> 529             obj = self._get_object_parser(self.data)
#     530         self.close()
#     531         return obj
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     544         obj = None
#     545         if typ == 'frame':
# --> 546             obj = FrameParser(json, **kwargs).parse()
#     547
#     548         if typ == 'series' or obj is None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in parse(self)
#     636
#     637         else:
# --> 638             self._parse_no_numpy()
#     639
#     640         if self.obj is None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     851         if orient == "columns":
#     852             self.obj = DataFrame(
# --> 853                 loads(json, precise_float=self.precise_float), dtype=None)
#     854         elif orient == "split":
#     855             decoded = {str(k): v for k, v in compat.iteritems(
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    7400             lengths = list(set(raw_lengths))
#    7401             if len(lengths) > 1:
# -> 7402                 raise ValueError('arrays must all be same length')
#    7403
#    7404             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
type(a['batter_id'][0])
# Out:
# str

# %%
df_a = pd.DataFrame(a)

# %%
def height(height_str):
    feet, inches = height_str.split("' ")
    feet = int(feet)
    inches = int(inches[:-1])
    return 12 * feet + inches

# %%
df_a['height'].map(height)
# Out:
# 0    79
# 1    78
# 2    73
# 3    74
# 4    75
# 5    77
# 6    75
# 7    77
# 8    76
# 9    75
# Name: height, dtype: int64

# %%
# Out:
# "'"

# %%
a['batter_id']
# Out:
# ['592450',
#  '519317',
#  '471865',
#  '443558',
#  '121347',
#  '608336',
#  '547180',
#  '573627',
#  '541645',
#  '543807']

# %%
pd.DataFrame(batter_final_dict)

# %%
8 * len(batter_id) /60
# Out:
# 100.13333333333334
