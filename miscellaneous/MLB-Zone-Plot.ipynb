# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('../data/final_for_preprocessing.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
with pd.option_context('display.max_columns', None):
    display(df.head())
# Out:
#   pitch_type  release_speed  release_pos_x  release_pos_z        player_name  \
# 0         CH           84.5        -3.4020         6.4696        Aaron Judge
# 1         FF           97.1        -2.8091         5.9279        Aaron Judge
# 2         CU           86.7        -1.5647         5.3406  Giancarlo Stanton
# 3         SL           89.5         2.0682         6.1177  Giancarlo Stanton
# 4         SL           84.7        -1.9795         5.6860        Aaron Judge
#
#    zone p_throws     bb_type  game_year     pfx_x     pfx_z  plate_x  plate_z  \
# 0   4.0        R  line_drive       2017 -0.900200  1.706600  -0.5499   2.6100
# 1   5.0        R  line_drive       2017 -1.194800  1.532500  -0.1538   2.9786
# 2   7.0        R  line_drive       2015  0.670208  0.093933  -0.3460   2.1220
# 3   8.0        L    fly_ball       2017 -0.130300 -0.210100  -0.1993   2.2053
# 4   5.0        R    fly_ball       2017 -0.456100  0.742100  -0.2071   3.1440
#
# ...

# %%
sns.set_style("white")
sns.set_color_codes()
plt.figure(figsize=(12,11))
plt.scatter(df.plate_x, df.plate_z)
plt.show()

# %%
pic = plt.imread('../plots/Zones.png')

# # urlretrieve returns a tuple with our image as the first 
# # element and imread reads in the image as a 
# # mutlidimensional numpy array so matplotlib can plot it
# harden_pic = plt.imread(pic[0])

# # plot the image
plt.imshow(pic)
plt.show()

# %%
df.zone
# Out:
# 0         4.0
# 1         5.0
# 2         7.0
# 3         8.0
# 4         5.0
# 5        13.0
# 6         8.0
# 7         4.0
# 8         4.0
# 9         2.0
# 10        5.0
# 11        2.0
# 12        6.0
# 13        4.0
# 14        5.0
# 15        5.0
# 16        5.0
# 17        5.0
# 18        5.0
# 19        9.0
# 20        9.0
# 21        4.0
# 22        8.0
# 23        5.0
# 24        7.0
# 25       11.0
# 26        5.0
# 27        4.0
# 28        4.0
# 29        4.0
#          ...
# 16351     5.0
# 16352     8.0
# 16353    12.0
# 16354     7.0
# 16355     9.0
# 16356    12.0
# 16357     6.0
# 16358     9.0
# 16359     5.0
# 16360     7.0
# 16361    12.0
# 16362     8.0
# 16363    13.0
# 16364    13.0
# 16365    11.0
# 16366     6.0
# 16367    11.0
# 16368    11.0
# 16369     4.0
# 16370     5.0
# 16371    11.0
# 16372     7.0
# 16373     3.0
# 16374     1.0
# 16375     5.0
# 16376     9.0
# 16377     4.0
# 16378     4.0
# 16379    12.0
# 16380    11.0
# ...

# %%
pic = plt.imread('../plots/Zones.png')
aspect= pic.shape[0] * 1.0 / pic.shape[1]

# %%
aspect
# Out:
# 0.9821428571428571

# %%
df.plate_x.min(), df.plate_x.max()
# Out:
# (-6.334, 1.5779)

# %%
df.plate_z.min(), df.plate_z.max()
# Out:
# (-4.81, 6.556)

# %%
df.sz_top.min(), df.sz_top.max()
# Out:
# (2.7325, 4.15)

# %%
df.sz_bot.min(), df.sz_bot.max()
# Out:
# (1.0447, 2.0434)

# %%
pic = plt.imread('../plots/Zones.png')
aspect= pic.shape[0] * 1.0 / pic.shape[1]
axis = (0, 1, -3, -4)

plt.imshow(pic,
          cmap=plt.get_cmap('gray'),
          extent=axis,
          aspect=aspect)


# sns.set_style("white")
# sns.set_color_codes()
# plt.figure(figsize=(12,11))
# plt.scatter(df.sz_bot, df.sz_top)
# plt.show()

plt.tight_layout()

# %%
from matplotlib.patches import Circle, Rectangle, Arc
from PIL import Image
import matplotlib.patches as patches

# %%
df_zone['zone_square'] = df['zone']
df_zone.loc[df_zone['zone_square']==1] = patches.Rectangle((68,65),104,100,linewidth=3,edgecolor='r',facecolor='none')
# Out:
# /Users/nelson/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/nelson/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
im = np.array(Image.open('../plots/Zones.png'))
fig, ax = plt.subplots(figsize=(12,8))
ax.imshow(im)
zone_1 = patches.Rectangle((68,65),104,100,linewidth=3,edgecolor='r',facecolor='none')

ax.add_patch(zone_1)
plt.tight_layout();

# %%
im = np.array(Image.open('../plots/Zones.png'))
fig, ax = plt.subplots(figsize=(12,8))
ax.imshow(im)
plt.tight_layout();

# %%
df_zone.drop('zone_square', axis=1, inplace=True)
# Out:
# /Users/nelson/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_zone['zone'].value_counts()
# Out:
# 5.0     3700
# 4.0     2350
# 8.0     1980
# 6.0     1697
# 2.0     1516
# 7.0     1223
# 9.0      871
# 1.0      856
# 3.0      726
# 13.0     487
# 11.0     435
# 12.0     286
# 14.0     254
# Name: zone, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
temp_list_x = []
temp_list_y = []
for i in df['zone']:
    if i == 1 or 4 or 7
df['zone']
# Out:
# array([4.0, 5.0, 7.0, ..., 4.0, 12.0, 11.0], dtype=object)

# %%
df_zone['x'] = df['zone']
df_zone.loc[df_zone['x']==1]  = 125
df_zone.loc[df_zone['x']==2]  = 225
df_zone.loc[df_zone['x']==3]  = 325
df_zone.loc[df_zone['x']==4]  = 125
df_zone.loc[df_zone['x']==5]  = 225
df_zone.loc[df_zone['x']==6]  = 325
df_zone.loc[df_zone['x']==7]  = 125
df_zone.loc[df_zone['x']==8]  = 225
df_zone.loc[df_zone['x']==9]  = 325
df_zone.loc[df_zone['x']==11] = 25
df_zone.loc[df_zone['x']==12] = 425
df_zone.loc[df_zone['x']==13] = 25
df_zone.loc[df_zone['x']==14] = 425

# %%
df_zone['y'] = df['zone']
df_zone.loc[df_zone['y']==1]  = 125
df_zone.loc[df_zone['y']==2]  = 125
df_zone.loc[df_zone['y']==3]  = 125
df_zone.loc[df_zone['y']==4]  = 225
df_zone.loc[df_zone['y']==5]  = 225
df_zone.loc[df_zone['y']==6]  = 225
df_zone.loc[df_zone['y']==7]  = 325
df_zone.loc[df_zone['y']==8]  = 325
df_zone.loc[df_zone['y']==9]  = 325
df_zone.loc[df_zone['y']==11] = 25
df_zone.loc[df_zone['y']==12] = 25
df_zone.loc[df_zone['y']==13] = 400
df_zone.loc[df_zone['y']==14] = 400

# %%
df_zone.drop(df_zone.index[16374],inplace=True)

# %%
df_zone2 = df[['zone']]
df_zone2.sort_values('zone', inplace=True)
df_zone2.reset_index(inplace=True)

# %%
x_lst = []
for x in df_zone2['zone']:
    if x == 1:
        x_lst.append(125)
    if x == 2:
        x_lst.append(225)
    if x == 3:
        x_lst.append(325)
    if x == 4:
        x_lst.append(125)
    if x == 5:
        x_lst.append(225)
    if x == 6:
        x_lst.append(325)
    if x == 7:
        x_lst.append(125)
    if x == 8:
        x_lst.append(225)
    if x == 9:
        x_lst.append(325)
    if x == 11:
        x_lst.append(25)
    if x == 12:
        x_lst.append(425)
    if x == 13:
        x_lst.append(25)
    if x == 14:
        x_lst.append(425)

# %%
y_lst = []
for x in df_zone2['zone']:
    if x == 1:
        y_lst.append(125)
    if x == 2:
        y_lst.append(125)
    if x == 3:
        y_lst.append(125)
    if x == 4:
        y_lst.append(225)
    if x == 5:
        y_lst.append(225)
    if x == 6:
        y_lst.append(225)
    if x == 7:
        y_lst.append(325)
    if x == 8:
        y_lst.append(325)
    if x == 9:
        y_lst.append(325)
    if x == 11:
        y_lst.append(25)
    if x == 12:
        y_lst.append(25)
    if x == 13:
        y_lst.append(400)
    if x == 14:
        y_lst.append(400)

# %%
df_zone2['x'] = x_lst

# %%
df_zone2['y'] = y_lst

# %%
df_zone2.drop('index', axis=1, inplace=True)

# %%
df_zone2.head()
# Out:
#    zone    x    y
# 0   1.0  125  125
# 1   1.0  125  125
# 2   1.0  125  125
# 3   1.0  125  125
# 4   1.0  125  125

# %%
df_zone = df_zone2.groupby(['zone','x','y']).agg({'zone':'count'})

# %%
df_zone.columns = ['weight']

# %%
df_zone.reset_index(inplace=True)

# %%
sns.scatterplot(df_zone['x'], y=df_zone['y'], hue=df_zone['weight'], size=df_zone['weight'], s=5000)

# %%
plt.figure(figsize=(17,8))

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)

im = np.array(Image.open('../plots/Zones.png'))
plt.imshow(im)
sns.scatterplot(df_zone['x'], 
                y=df_zone['y'],  
                size=df_zone['weight'], 
                palette=cmap, 
                sizes=(800, 10000))



leg = plt.legend(title='Home Runs by Zone')
leg.get_frame().set_edgecolor('k')
leg.get_frame().set_linewidth(1)

plt.tight_layout();
